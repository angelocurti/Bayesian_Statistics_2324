# %%
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random
import numpy as np
import jax
import scipy
from sklearn.metrics import adjusted_rand_score
# !pip install mycolorpy
from scipy.stats import multivariate_normal
# Out:
# Collecting mycolorpy
#   Downloading mycolorpy-1.5.1.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mycolorpy) (1.16.0)
# Building wheels for collected packages: mycolorpy
#   Building wheel for mycolorpy (setup.py) ... done
#   Created wheel for mycolorpy: filename=mycolorpy-1.5.1-py3-none-any.whl size=3851 sha256=404358dc9f1288d2c6857cc6aece4b67e80adcefbaa68e1effffb19731dba612
#   Stored in directory: /root/.cache/pip/wheels/d6/1d/04/f8bfb8b04e3daba330b3f377c041b89304271ff98fb6704946
# Successfully built mycolorpy
# Installing collected packages: mycolorpy
# Successfully installed mycolorpy-1.5.1

# %% [markdown]
# # Generazione Dati

# %%
from IPython.utils.sysinfo import num_cpus

# numero di cluster
K=5

# dimensione del campione
d=2

# numero di sample
N=1000

seed=2022
key = random.PRNGKey(seed)
# vectors of mean of clusters
sigma=5
mu=random.normal(key,(K,d))*sigma

# cluster assignment
key = random.PRNGKey(2)
c=random.categorical(key,(1/K)*jnp.ones(shape=(K,)),axis=0,shape=(N,))
C=np.zeros(shape=(N,K))
for i in range(N):
  C[i,c[i]]=1
C=jnp.array(C)

# Data
X=jnp.matmul(C,mu)+random.normal(key,(N,d))

# %%
import matplotlib.pyplot as plt

for i in range(K):
  plt.scatter(X[c==i,0],X[c==i,1])
plt.show()

# %% [markdown]
# # Variational Inference
#
# We construct the model for our VI algorithm, we stick to the notation of the paper. Our model is described by:
#
# \begin{align*}
#     \mu_k\ \mid x &\stackrel{\tiny\mbox{ind}}{\sim} \mathcal{N}_d\left(m_k, s^2_k\ \mathbb{I}_d\right) \qquad \qquad \ \ \  k=1,...,K\\
#     x_i \mid c_i,μ &\stackrel{\tiny\mbox{ind}}{\sim} \mathcal{N}_d\left(c^T_iμ, \ \mathbb{I}_d\ \right) \qquad  \qquad \ \ \ \  i=1,...,n \\
#     \mu_k &\stackrel{\tiny\mbox{iid}}{\sim}\mathcal{N}_d\left(0, \ \sigma^2\  \mathbb{I}_d\right) \qquad \qquad \ \ \ \   k=1,...,K\\
#     c_ i&\stackrel{\tiny\mbox{iid}}{\sim} Cat(\frac{1}{K},...,\frac{1}{K}) \qquad \qquad  i=1,...,n
# \end{align*}

# %% [markdown]
# Considering $q(c_i=k)$=$𝝋_{ik}$ we can define the variational update for the ith cluster assignment as
#
# \begin{align*}
#   𝜑_{ik}∝exp[\ \mathbb{E}[\mu_k;\ m_k,\ s_k^2]x_i-\mathbb{E}[\mu_k^2;\ m_k,\ s_k^2]/2\ ]
# \end{align*}
#
# Then we can define the updates for the variational density of the kth mixture component q($\mu_k$) in terms of variational mean and variance
#
#
# \begin{align*}
#     \hat{m_k}=\frac{\sum_{i}^{}𝝋_{ik}x_i}{\frac{1}{\sigma^2}+\sum_{i}^{}𝝋_{ik}} \qquad \qquad \hat{s_k}^2=\frac{1}{\frac{1}{\sigma^2}+\sum_{i}^{}𝝋_{ik}}
# \end{align*}
#
#
# VI can be considered as an optimization problem, so we need to define the function to be optimized, which is the ELBO.
# \begin{align*}
#     ELBO(\hat{m},\hat{s}^2,𝜑)=\sum_{k=1}^{K}\mathbb{E}[\log p(\mu_k);\ \hat{m_k},\ \hat{s_k}^2] \  +\\  \sum_{i=1}^{n}(\ \mathbb{E}[\log p(c_i);\ 𝜑_i]+\mathbb{E}[\log p(x_i|c_i,μ);\ 𝜑_i,\ \hat{m},\ \hat{s}^2]\ )\ + \  \\ - \sum_{i=1}^{n} \mathbb{E}[\log q(c_i;\ 𝜑_i)]- \sum_{k=1}^{K} \mathbb{E}[\log q(\mu_k;\ \hat{m_k},\ \hat{s_k}^2)]
# \end{align*}
#
# \\
# Considering $k=1,...,K$ and $i=1,...,n$

# %%
#def update_phi(data,phi,m,s2):
#  for i in jnp.arange(data.shape[0]):
#    for k in jnp.arange(phi.shape[1]):
#      phi[i,k]=jnp.exp(jnp.matmul(m[k,:],data[i,:].transpose())-(s2[k]+jnp.matmul(m[k,:],m[k,:].transpose()))/2) # non sono così sicuro della formula per mk^2
#    phi[i,:]=phi[i,:]/jnp.sum(phi[i,:])
#  return phi

def update_phi(data, phi, m, s2):
    M=jnp.matmul(m,m.T)
    log_likelihood = jnp.matmul(data,m.T) - 0.5 * jnp.matmul(jnp.ones(shape=(N,1)),(s2.T + jnp.resize(jnp.diag(M),(K,1)).T))
    # updated_phi=scipy.special.softmax(log_likelihood)
    updated_phi = jnp.nan_to_num(jnp.exp(log_likelihood),nan=10**-10,posinf=10**5) + 10**-10 # to avoid round zeros that make the ELBO go nan

    updated_phi /= jnp.sum(updated_phi,axis=1,keepdims=True)


    def true_fun(updated_phi):
      updated_phi +=10**-10
      updated_phi /= jnp.sum(updated_phi,axis=1,keepdims=True)
      return updated_phi

    def false_fun(updated_phi):
      return updated_phi

    updated_phi=jax.lax.cond((jnp.sum(updated_phi==0)>0), true_fun, false_fun,updated_phi)

    return updated_phi

update_phi_jit=jit(update_phi)


def update_mean_and_variance(data,phi,sigma):
  K=phi.shape[1]
  d=data.shape[1]
  N=data.shape[0]
  updated_m=(jnp.matmul(phi.T,data)/(1/sigma**2*jnp.ones(shape=(K,d))+jnp.matmul(jnp.resize(jnp.sum(phi,axis=0),(1,K)).T,jnp.ones(shape=(1,d)))))
  updated_s2=(1/(1/sigma**2*jnp.ones(shape=(K,1))+jnp.resize(jnp.sum(phi,axis=0),(1,K)).T))
  return updated_m,updated_s2

update_mean_and_variance_jit=jit(update_mean_and_variance)


def compute_ELBO(m,s2,phi,data):
  # when computing the ELBO value, we omit constants because once we compute the improvement they would have a total of 0
  # Fn stands for the nth component of the formula (21) in the review paper
  d=m.shape[1]
  M=jnp.matmul(m,m.T)

  F1=-0.5/sigma**2 *jnp.sum( d*s2+jnp.diag(M))

  # F2= -log(K) sum over k from 1 to K => constant in every iteration

  F3=-0.5*jnp.sum(jnp.matmul(phi.T,jnp.diag(jnp.matmul(data,data.T))))+jnp.sum(jnp.diag(jnp.matmul(phi.T,jnp.matmul(data,m.T))))-0.5*d*jnp.sum(jnp.matmul(phi,s2))
  F3+=-0.5*jnp.sum(jnp.matmul(phi,jnp.diag(M)))
  # -d/2*jnp.log(2*jnp.pi)*phi[i,k] summed over i and k should be constant over time, since phi[i,:] is a probability it should sum N every time

  F4=jnp.sum(jnp.log(phi)*phi)

  F5=-d/2*jnp.sum(jnp.log(s2))

  return F1+F3-F4-F5

compute_ELBO_jit=jit(compute_ELBO)

# %%
# FUNCTION FOR VARIATIONAL INFERENCE
# Notation of the paper

def single_iteration_VI(data,K,sigma,i,nMAX,tol):
    N=data.shape[0]
    d=data.shape[1]
    key = random.PRNGKey(i*seed)
    phi=random.uniform(key,minval=0,maxval=1,shape=(N,K))
    phi/=jnp.sum(phi,axis=1,keepdims=True)
    m=random.normal(key,shape=(K,d))*sigma
    s2=random.uniform(key,minval=0,maxval=10,shape=(K,1))
    improvement=1
    ELBO_old=0 # probabilmente questo andrà modificato
    ELBO_new=compute_ELBO_jit(m,s2,phi,data)
    nit=0

    def cond(state):
      _,_,_,_,_,nit,ELBO,improvement,tol,nMAX=state
      return (((improvement>tol) & (nit<nMAX)) | (ELBO==jnp.nan))

    def iteration_while(state):
      data,m,s2,phi,sigma,nit,ELBO_new,improvement,tol,nMAX=state
      phi=update_phi_jit(data,phi,m,s2)
      m,s2=update_mean_and_variance_jit(data,phi,sigma)
      ELBO_old=ELBO_new
      ELBO_new=compute_ELBO_jit(m,s2,phi,data)
      improvement=ELBO_new-ELBO_old
      nit+=1
      return (data,m,s2,phi,sigma,nit,ELBO_new,improvement,tol,nMAX)

    state=(data,m,s2,phi,sigma,nit,ELBO_new,improvement,tol,nMAX)
    _,m,s2,phi,_,nit,ELBO_new,_,_,_=jax.lax.while_loop(cond_fun=cond,body_fun=iteration_while,init_val=state)

      #print('Iter ',nit,'\t ELBO: ',ELBO_new,'\t Improvement: ',improvement,'\n')
      #print('=================================================\n')
    return  m,s2,phi,ELBO_new,nit

single_iteration_VI_jit=jit(single_iteration_VI,static_argnames=['K','nMAX','tol'])


def VI(data,K,sigma,nMAX,n_iniz,tol):
  # creating our variables as estimation of parameters for posterior probabilities
  # jax arrays are immutable, so I don't know how to create these variables in jax and use them
  # I iniialize them randomly, since there is no a-priori starting point which is best than others
  ELBO_max=0
  for i in range(n_iniz):
    m,s2,phi,ELBO_new,nit=single_iteration_VI_jit(data,K,sigma,i,nMAX,tol)
    if i==0:
      ELBO_max=ELBO_new
      m_max=m
      s2_max=s2
      phi_max=phi
      n_max=0
    print('Initialization number: ',i+1,'\t ELBO: ',ELBO_new,'\t N_iterations: ',nit)
    print('=================================================\n')
    if ELBO_new>ELBO_max:
      ELBO_max=ELBO_new
      m_max=m
      s2_max=s2
      phi_max=phi
      n_max=i
  print('Best initialization at ',n_max+1,' \t ELBO: ',ELBO_max,'\n\n')
  return m_max,s2_max,phi_max

VI_jit=jit(VI)

# %%
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp

def plot_clusters(data, phi, means):
    # Get the cluster assignments
    cluster_assignments = jnp.argmax(phi, axis=1)

    # Number of clusters
    num_clusters = means.shape[0]

    # Create a list of colors for plotting
    #colors = plt.colormaps()
    colors=mcp.gen_color(cmap="viridis",n=K)
    print(colors)

    # Scatter plot each data point with its assigned color
    plt.figure(figsize=(8, 6))
    for cluster in range(num_clusters):
        plt.scatter(data[cluster_assignments == cluster, 0], data[cluster_assignments == cluster, 1], c=colors[cluster], label=f'Cluster {cluster}')

    # Plot the cluster means
    for cluster in range(num_clusters):
        plt.scatter(means[cluster, 0], means[cluster, 1], marker='x', color='red', s=100, label=f'Mean Cluster {cluster}')

    plt.legend()
    plt.title('Cluster Visualization')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# %%
# %%timeit
tol=10**-16
m,s2,phi=VI(X,K,sigma,10000,100,tol)
#print(m,'\n',mu)
#print(s2)
#print(phi,'\n',C)
# Out:
# Initialization number:  1 	 ELBO:  -832.81824 	 N_iterations:  23
# =================================================
#
# Initialization number:  2 	 ELBO:  -832.8225 	 N_iterations:  10
# =================================================
#
# Initialization number:  3 	 ELBO:  -988.8818 	 N_iterations:  34
# =================================================
#
# Initialization number:  4 	 ELBO:  -832.8223 	 N_iterations:  28
# =================================================
#
# Initialization number:  5 	 ELBO:  -900.92993 	 N_iterations:  18
# =================================================
#
# Initialization number:  6 	 ELBO:  -832.8166 	 N_iterations:  20
# =================================================
#
# Initialization number:  7 	 ELBO:  -832.82043 	 N_iterations:  22
# =================================================
#
# Initialization number:  8 	 ELBO:  -832.82587 	 N_iterations:  26
# =================================================
#
# Initialization number:  9 	 ELBO:  -832.8169 	 N_iterations:  27
# =================================================
#
# Initialization number:  10 	 ELBO:  -832.81903 	 N_iterations:  15
# =================================================
#
# Initialization number:  11 	 ELBO:  -832.8202 	 N_iterations:  34
# =================================================
#
# Initialization number:  12 	 ELBO:  -988.8989 	 N_iterations:  16
# =================================================
#
# Initialization number:  13 	 ELBO:  -832.81976 	 N_iterations:  17
# =================================================
#
# Initialization number:  14 	 ELBO:  -988.8738 	 N_iterations:  22
# =================================================
#
# Initialization number:  15 	 ELBO:  -988.8863 	 N_iterations:  20
# =================================================
#
# Initialization number:  16 	 ELBO:  -832.81586 	 N_iterations:  26
# =================================================
#
# Initialization number:  17 	 ELBO:  -832.819 	 N_iterations:  30
# =================================================
#
# Initialization number:  18 	 ELBO:  -988.8948 	 N_iterations:  23
# =================================================
#
# Initialization number:  19 	 ELBO:  -832.8217 	 N_iterations:  24
# =================================================
#
# Initialization number:  20 	 ELBO:  -1130.899 	 N_iterations:  15
# =================================================
#
# Initialization number:  21 	 ELBO:  -832.81915 	 N_iterations:  24
# =================================================
#
# Initialization number:  22 	 ELBO:  -988.8852 	 N_iterations:  14
# =================================================
#
# Initialization number:  23 	 ELBO:  -832.8322 	 N_iterations:  25
# =================================================
#
# Initialization number:  24 	 ELBO:  -955.4739 	 N_iterations:  23
# =================================================
#
# Initialization number:  25 	 ELBO:  -832.8171 	 N_iterations:  19
# =================================================
#
# Initialization number:  26 	 ELBO:  -1130.9005 	 N_iterations:  12
# =================================================
#
# Initialization number:  27 	 ELBO:  -988.88745 	 N_iterations:  33
# =================================================
#
# Initialization number:  28 	 ELBO:  -988.8767 	 N_iterations:  13
# =================================================
#
# Initialization number:  29 	 ELBO:  -832.8265 	 N_iterations:  20
# =================================================
#
# Initialization number:  30 	 ELBO:  -832.8241 	 N_iterations:  25
# =================================================
#
# Initialization number:  31 	 ELBO:  -1130.9001 	 N_iterations:  14
# =================================================
#
# Initialization number:  32 	 ELBO:  -832.8283 	 N_iterations:  19
# =================================================
#
# Initialization number:  33 	 ELBO:  -832.8159 	 N_iterations:  27
# =================================================
#
# Initialization number:  34 	 ELBO:  -1130.8967 	 N_iterations:  14
# =================================================
#
# Initialization number:  35 	 ELBO:  -988.89026 	 N_iterations:  28
# =================================================
#
# Initialization number:  36 	 ELBO:  -1130.8939 	 N_iterations:  10
# =================================================
#
# Initialization number:  37 	 ELBO:  -832.82806 	 N_iterations:  23
# =================================================
#
# Initialization number:  38 	 ELBO:  -1130.8966 	 N_iterations:  14
# =================================================
#
# Initialization number:  39 	 ELBO:  -832.8217 	 N_iterations:  21
# =================================================
#
# Initialization number:  40 	 ELBO:  -832.8218 	 N_iterations:  25
# =================================================
#
# Initialization number:  41 	 ELBO:  -900.9281 	 N_iterations:  16
# =================================================
#
# Initialization number:  42 	 ELBO:  -988.9201 	 N_iterations:  27
# =================================================
#
# Initialization number:  43 	 ELBO:  -832.8175 	 N_iterations:  20
# =================================================
#
# Initialization number:  44 	 ELBO:  -988.8894 	 N_iterations:  13
# =================================================
#
# Initialization number:  45 	 ELBO:  -832.8202 	 N_iterations:  25
# =================================================
#
# Initialization number:  46 	 ELBO:  -832.81555 	 N_iterations:  23
# =================================================
#
# Initialization number:  47 	 ELBO:  -832.8145 	 N_iterations:  28
# =================================================
#
# Initialization number:  48 	 ELBO:  -832.81836 	 N_iterations:  36
# =================================================
#
# Initialization number:  49 	 ELBO:  -1130.8984 	 N_iterations:  14
# =================================================
#
# Initialization number:  50 	 ELBO:  -988.8996 	 N_iterations:  24
# =================================================
#
# Initialization number:  51 	 ELBO:  -832.8193 	 N_iterations:  29
# =================================================
#
# Initialization number:  52 	 ELBO:  -832.81604 	 N_iterations:  25
# =================================================
#
# Initialization number:  53 	 ELBO:  -900.9326 	 N_iterations:  15
# =================================================
#
# Initialization number:  54 	 ELBO:  -832.82605 	 N_iterations:  23
# =================================================
#
# Initialization number:  55 	 ELBO:  -832.83075 	 N_iterations:  24
# =================================================
#
# Initialization number:  56 	 ELBO:  -1130.8982 	 N_iterations:  15
# =================================================
#
# Initialization number:  57 	 ELBO:  -832.816 	 N_iterations:  25
# =================================================
#
# Initialization number:  58 	 ELBO:  -832.826 	 N_iterations:  21
# =================================================
#
# Initialization number:  59 	 ELBO:  -832.82635 	 N_iterations:  21
# =================================================
#
# Initialization number:  60 	 ELBO:  -832.8273 	 N_iterations:  16
# =================================================
#
# Initialization number:  61 	 ELBO:  -832.8275 	 N_iterations:  31
# =================================================
#
# Initialization number:  62 	 ELBO:  -955.4756 	 N_iterations:  14
# =================================================
#
# Initialization number:  63 	 ELBO:  -832.8155 	 N_iterations:  29
# =================================================
#
# Initialization number:  64 	 ELBO:  -832.8148 	 N_iterations:  18
# =================================================
#
# Initialization number:  65 	 ELBO:  -832.81976 	 N_iterations:  25
# =================================================
#
# Initialization number:  66 	 ELBO:  -988.8977 	 N_iterations:  37
# =================================================
#
# Initialization number:  67 	 ELBO:  -832.81775 	 N_iterations:  39
# =================================================
#
# Initialization number:  68 	 ELBO:  -832.8168 	 N_iterations:  19
# =================================================
#
# Initialization number:  69 	 ELBO:  -832.82715 	 N_iterations:  28
# =================================================
#
# Initialization number:  70 	 ELBO:  -832.8163 	 N_iterations:  43
# =================================================
#
# Initialization number:  71 	 ELBO:  -832.82416 	 N_iterations:  31
# =================================================
#
# Initialization number:  72 	 ELBO:  -832.82434 	 N_iterations:  32
# =================================================
#
# Initialization number:  73 	 ELBO:  -832.826 	 N_iterations:  23
# =================================================
#
# Initialization number:  74 	 ELBO:  -1130.9017 	 N_iterations:  13
# =================================================
#
# Initialization number:  75 	 ELBO:  -832.81885 	 N_iterations:  22
# =================================================
#
# Initialization number:  76 	 ELBO:  -832.81525 	 N_iterations:  26
# =================================================
#
# Initialization number:  77 	 ELBO:  -988.88324 	 N_iterations:  40
# =================================================
#
# Initialization number:  78 	 ELBO:  -832.8202 	 N_iterations:  28
# =================================================
#
# Initialization number:  79 	 ELBO:  -832.8168 	 N_iterations:  29
# =================================================
#
# Initialization number:  80 	 ELBO:  -988.8816 	 N_iterations:  33
# =================================================
#
# Initialization number:  81 	 ELBO:  -832.819 	 N_iterations:  25
# =================================================
#
# Initialization number:  82 	 ELBO:  -955.4742 	 N_iterations:  14
# =================================================
#
# Initialization number:  83 	 ELBO:  -988.88983 	 N_iterations:  32
# =================================================
#
# Initialization number:  84 	 ELBO:  -832.81616 	 N_iterations:  19
# =================================================
#
# Initialization number:  85 	 ELBO:  -832.81635 	 N_iterations:  14
# =================================================
#
# Initialization number:  86 	 ELBO:  -832.81824 	 N_iterations:  22
# =================================================
#
# Initialization number:  87 	 ELBO:  -832.8232 	 N_iterations:  31
# =================================================
#
# Initialization number:  88 	 ELBO:  -832.8197 	 N_iterations:  24
# =================================================
#
# Initialization number:  89 	 ELBO:  -832.8299 	 N_iterations:  28
# =================================================
#
# Initialization number:  90 	 ELBO:  -832.82745 	 N_iterations:  25
# =================================================
#
# Initialization number:  91 	 ELBO:  -988.8905 	 N_iterations:  24
# =================================================
#
# Initialization number:  92 	 ELBO:  -1130.9014 	 N_iterations:  11
# =================================================
#
# Initialization number:  93 	 ELBO:  -832.82587 	 N_iterations:  26
# =================================================
#
# Initialization number:  94 	 ELBO:  -832.8172 	 N_iterations:  36
# =================================================
#
# Initialization number:  95 	 ELBO:  -1130.8959 	 N_iterations:  14
# =================================================
#
# Initialization number:  96 	 ELBO:  -832.8176 	 N_iterations:  22
# =================================================
#
# Initialization number:  97 	 ELBO:  -832.8183 	 N_iterations:  32
# =================================================
#
# Initialization number:  98 	 ELBO:  -832.8204 	 N_iterations:  24
# =================================================
#
# Initialization number:  99 	 ELBO:  -900.9281 	 N_iterations:  19
# =================================================
#
# Initialization number:  100 	 ELBO:  -832.8257 	 N_iterations:  27
# =================================================
#
# Best initialization at  47  	 ELBO:  -832.8145

# %%
# Eslicitiamo la likehood di muk rispetto ai dati
n_cluster = np.sum(C, axis = 0)
m_post=1/(n_cluster.reshape((K,1))+1/sigma**2)*np.matmul(C.T,X)
s2_post=1/(n_cluster+1/sigma**2)
#n_cluster = np.sum(C, axis = 0)
#m_post=1/(1+1/sigma**2)/np.matmul(n_cluster.reshape((K,1)),np.ones(shape=(1,d)))*np.matmul(C.T,X)
#s2_post=1/(1+1/sigma**2)/n_cluster

plot_clusters(X, phi, m)

for i in range(K):
  plt.scatter(X[c==i,0],X[c==i,1])
  plt.scatter(m_post[i, 0], m_post[i, 1], marker='x', color='red', s=100, label=f'Mean Cluster {i}')

plt.show()
# Out:
# ['#440154', '#3b528b', '#21918c', '#5ec962', '#fde725']

# %% [markdown]
# Il codice che segue è un'idea di metrica di errore

# %%
def error_measure(m_real,s2_real,clus_real,m_pred,s2_pred,clus_pred):
  K=clus_pred.shape[1]
  N=clus_pred.shape[0]
  weights1=1/K*np.ones((K,))
  weights2=np.mean(clus_pred,axis=1)
  mix1=0
  mix2=0
  inter=0
  d=m_real.shape[1]

  for i in np.arange(K):
    for j in np.arange(K):
      s2_ij=s2_real[i]+s2_real[j]
      mix1+=weights1[i]*weights1[j]*multivariate_normal.pdf(m_real[i,],m_real[j,],s2_ij*np.eye(d))
      s2_ij=s2_pred[i]+s2_pred[j]
      mix2+=weights2[i]*weights2[j]*multivariate_normal.pdf(m_pred[i,],m_pred[j,],s2_ij*np.eye(d))
      s2_ij=s2_real[i]+s2_pred[j]
      inter+=weights1[i]*weights2[j]*multivariate_normal.pdf(m_real[i,],m_pred[j,],s2_ij*np.eye(d))

  error_m_s2=mix1+mix2-2*inter
  clus_real_num=np.empty((N,))
  clus_pred_num=np.empty((N,))
  for i in np.arange(N):
    clus_real_num[i]=np.argmax(clus_real[i,])
    clus_pred_num[i]=np.argmax(clus_pred[i,])

  error_clust=1-adjusted_rand_score(clus_real_num,clus_pred_num)
  return error_m_s2,error_clust

# %%
error_m_s2,error_clust=error_measure(m_post,s2_post,C,m,s2,phi)
error_m_s2,error_clust
# Out:
# (Array(0.99773455, dtype=float32), 0.24206464457728294)

# %% [markdown]
# ## VALUTAZIONE ERRORE E TEMPO

# %%
# numero di cluster
K=5

# dimensione del campione
d=15

# Numero di sample
N=1000

seed=2022
key = random.PRNGKey(seed)
# vectors of mean of clusters
sigma=5
mu=random.normal(key,(K,d))*sigma

# cluster assignment
key = random.PRNGKey(2)
c=random.categorical(key,(1/K)*jnp.ones(shape=(K,)),axis=0,shape=(N,))
C=np.zeros(shape=(N,K))
for i in range(N):
  C[i,c[i]]=1
C=jnp.array(C)

# Data
X=jnp.matmul(C,mu)+random.normal(key,(N,d))

# %%
# %%timeit
tol=10**-16
m,s2,phi=VI(X,K,sigma,10000,100,tol)
# Out:
# Initialization number:  1 	 ELBO:  -92477.2 	 N_iterations:  3
# =================================================
#
# Initialization number:  2 	 ELBO:  -29953.46 	 N_iterations:  2
# =================================================
#
# Initialization number:  3 	 ELBO:  -104458.195 	 N_iterations:  2
# =================================================
#
# Initialization number:  4 	 ELBO:  -65758.9 	 N_iterations:  9
# =================================================
#
# Initialization number:  5 	 ELBO:  -100805.96 	 N_iterations:  4
# =================================================
#
# Initialization number:  6 	 ELBO:  -123446.17 	 N_iterations:  2
# =================================================
#
# Initialization number:  7 	 ELBO:  -92099.586 	 N_iterations:  3
# =================================================
#
# Initialization number:  8 	 ELBO:  -65274.895 	 N_iterations:  4
# =================================================
#
# Initialization number:  9 	 ELBO:  -97055.75 	 N_iterations:  4
# =================================================
#
# Initialization number:  10 	 ELBO:  -130767.98 	 N_iterations:  2
# =================================================
#
# Initialization number:  11 	 ELBO:  -85241.35 	 N_iterations:  4
# =================================================
#
# Initialization number:  12 	 ELBO:  -73005.26 	 N_iterations:  7
# =================================================
#
# Initialization number:  13 	 ELBO:  -124139.16 	 N_iterations:  2
# =================================================
#
# Initialization number:  14 	 ELBO:  -94792.18 	 N_iterations:  5
# =================================================
#
# Initialization number:  15 	 ELBO:  -101125.24 	 N_iterations:  6
# =================================================
#
# Initialization number:  16 	 ELBO:  -66692.36 	 N_iterations:  6
# =================================================
#
# Initialization number:  17 	 ELBO:  -67981.625 	 N_iterations:  3
# =================================================
#
# Initialization number:  18 	 ELBO:  -103172.19 	 N_iterations:  2
# =================================================
#
# Initialization number:  19 	 ELBO:  -88732.91 	 N_iterations:  5
# =================================================
#
# Initialization number:  20 	 ELBO:  -88288.31 	 N_iterations:  4
# =================================================
#
# Initialization number:  21 	 ELBO:  -61494.418 	 N_iterations:  4
# =================================================
#
# Initialization number:  22 	 ELBO:  -71973.625 	 N_iterations:  4
# =================================================
#
# Initialization number:  23 	 ELBO:  -100545.07 	 N_iterations:  3
# =================================================
#
# Initialization number:  24 	 ELBO:  -76002.57 	 N_iterations:  6
# =================================================
#
# Initialization number:  25 	 ELBO:  -100672.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  26 	 ELBO:  -97434.695 	 N_iterations:  4
# =================================================
#
# Initialization number:  27 	 ELBO:  -97272.83 	 N_iterations:  4
# =================================================
#
# Initialization number:  28 	 ELBO:  -89169.19 	 N_iterations:  3
# =================================================
#
# Initialization number:  29 	 ELBO:  -61254.684 	 N_iterations:  6
# =================================================
#
# Initialization number:  30 	 ELBO:  -117609.79 	 N_iterations:  3
# =================================================
#
# Initialization number:  31 	 ELBO:  -100832.77 	 N_iterations:  5
# =================================================
#
# Initialization number:  32 	 ELBO:  -124568.0 	 N_iterations:  3
# =================================================
#
# Initialization number:  33 	 ELBO:  -57972.17 	 N_iterations:  5
# =================================================
#
# Initialization number:  34 	 ELBO:  -101663.164 	 N_iterations:  4
# =================================================
#
# Initialization number:  35 	 ELBO:  -72020.07 	 N_iterations:  5
# =================================================
#
# Initialization number:  36 	 ELBO:  -78046.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  37 	 ELBO:  -102177.62 	 N_iterations:  2
# =================================================
#
# Initialization number:  38 	 ELBO:  -72211.02 	 N_iterations:  5
# =================================================
#
# Initialization number:  39 	 ELBO:  -97431.82 	 N_iterations:  4
# =================================================
#
# Initialization number:  40 	 ELBO:  -67935.08 	 N_iterations:  8
# =================================================
#
# Initialization number:  41 	 ELBO:  -93430.11 	 N_iterations:  3
# =================================================
#
# Initialization number:  42 	 ELBO:  -90905.58 	 N_iterations:  5
# =================================================
#
# Initialization number:  43 	 ELBO:  -97630.71 	 N_iterations:  5
# =================================================
#
# Initialization number:  44 	 ELBO:  -92771.19 	 N_iterations:  5
# =================================================
#
# Initialization number:  45 	 ELBO:  -81334.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  46 	 ELBO:  -60614.727 	 N_iterations:  6
# =================================================
#
# Initialization number:  47 	 ELBO:  -96777.82 	 N_iterations:  6
# =================================================
#
# Initialization number:  48 	 ELBO:  -123396.58 	 N_iterations:  3
# =================================================
#
# Initialization number:  49 	 ELBO:  -75629.85 	 N_iterations:  5
# =================================================
#
# Initialization number:  50 	 ELBO:  -94784.06 	 N_iterations:  4
# =================================================
#
# Initialization number:  51 	 ELBO:  -98441.96 	 N_iterations:  2
# =================================================
#
# Initialization number:  52 	 ELBO:  -101232.56 	 N_iterations:  5
# =================================================
#
# Initialization number:  53 	 ELBO:  -130583.9 	 N_iterations:  3
# =================================================
#
# Initialization number:  54 	 ELBO:  -100561.71 	 N_iterations:  2
# =================================================
#
# Initialization number:  55 	 ELBO:  -97739.266 	 N_iterations:  6
# =================================================
#
# Initialization number:  56 	 ELBO:  -123396.58 	 N_iterations:  4
# =================================================
#
# Initialization number:  57 	 ELBO:  -100394.55 	 N_iterations:  5
# =================================================
#
# Initialization number:  58 	 ELBO:  -89812.43 	 N_iterations:  2
# =================================================
#
# Initialization number:  59 	 ELBO:  -69064.88 	 N_iterations:  5
# =================================================
#
# Initialization number:  60 	 ELBO:  -103613.01 	 N_iterations:  6
# =================================================
#
# Initialization number:  61 	 ELBO:  -117725.02 	 N_iterations:  2
# =================================================
#
# Initialization number:  62 	 ELBO:  -93386.92 	 N_iterations:  5
# =================================================
#
# Initialization number:  63 	 ELBO:  -90035.516 	 N_iterations:  4
# =================================================
#
# Initialization number:  64 	 ELBO:  -98904.97 	 N_iterations:  5
# =================================================
#
# Initialization number:  65 	 ELBO:  -65758.9 	 N_iterations:  7
# =================================================
#
# Initialization number:  66 	 ELBO:  -109137.94 	 N_iterations:  4
# =================================================
#
# Initialization number:  67 	 ELBO:  -95057.4 	 N_iterations:  7
# =================================================
#
# Initialization number:  68 	 ELBO:  -48090.652 	 N_iterations:  7
# =================================================
#
# Initialization number:  69 	 ELBO:  -100093.01 	 N_iterations:  4
# =================================================
#
# Initialization number:  70 	 ELBO:  -73589.57 	 N_iterations:  5
# =================================================
#
# Initialization number:  71 	 ELBO:  -90575.92 	 N_iterations:  6
# =================================================
#
# Initialization number:  72 	 ELBO:  -91504.98 	 N_iterations:  3
# =================================================
#
# Initialization number:  73 	 ELBO:  -69468.28 	 N_iterations:  4
# =================================================
#
# Initialization number:  74 	 ELBO:  -76288.53 	 N_iterations:  6
# =================================================
#
# Initialization number:  75 	 ELBO:  -81428.87 	 N_iterations:  4
# =================================================
#
# Initialization number:  76 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  77 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  78 	 ELBO:  -82138.04 	 N_iterations:  6
# =================================================
#
# Initialization number:  79 	 ELBO:  -98391.86 	 N_iterations:  4
# =================================================
#
# Initialization number:  80 	 ELBO:  -77883.914 	 N_iterations:  6
# =================================================
#
# Initialization number:  81 	 ELBO:  -102576.38 	 N_iterations:  3
# =================================================
#
# Initialization number:  82 	 ELBO:  -65369.91 	 N_iterations:  10
# =================================================
#
# Initialization number:  83 	 ELBO:  -97253.95 	 N_iterations:  3
# =================================================
#
# Initialization number:  84 	 ELBO:  -110067.21 	 N_iterations:  5
# =================================================
#
# Initialization number:  85 	 ELBO:  -86376.484 	 N_iterations:  5
# =================================================
#
# Initialization number:  86 	 ELBO:  -101022.266 	 N_iterations:  2
# =================================================
#
# Initialization number:  87 	 ELBO:  -76254.22 	 N_iterations:  5
# =================================================
#
# Initialization number:  88 	 ELBO:  -60064.137 	 N_iterations:  5
# =================================================
#
# Initialization number:  89 	 ELBO:  -90845.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  90 	 ELBO:  -96048.03 	 N_iterations:  2
# =================================================
#
# Initialization number:  91 	 ELBO:  -78093.87 	 N_iterations:  6
# =================================================
#
# Initialization number:  92 	 ELBO:  -94676.055 	 N_iterations:  5
# =================================================
#
# Initialization number:  93 	 ELBO:  -85397.73 	 N_iterations:  10
# =================================================
#
# Initialization number:  94 	 ELBO:  -95100.086 	 N_iterations:  5
# =================================================
#
# Initialization number:  95 	 ELBO:  -100452.54 	 N_iterations:  6
# =================================================
#
# Initialization number:  96 	 ELBO:  -95588.38 	 N_iterations:  4
# =================================================
#
# Initialization number:  97 	 ELBO:  -54463.04 	 N_iterations:  7
# =================================================
#
# Initialization number:  98 	 ELBO:  -97465.6 	 N_iterations:  5
# =================================================
#
# Initialization number:  99 	 ELBO:  -95242.62 	 N_iterations:  4
# =================================================
#
# Initialization number:  100 	 ELBO:  -74653.516 	 N_iterations:  3
# =================================================
#
# Best initialization at  2  	 ELBO:  -29953.46
#
#
# Initialization number:  1 	 ELBO:  -92477.2 	 N_iterations:  3
# =================================================
#
# Initialization number:  2 	 ELBO:  -29953.46 	 N_iterations:  2
# =================================================
#
# Initialization number:  3 	 ELBO:  -104458.195 	 N_iterations:  2
# =================================================
#
# Initialization number:  4 	 ELBO:  -65758.9 	 N_iterations:  9
# =================================================
#
# Initialization number:  5 	 ELBO:  -100805.96 	 N_iterations:  4
# =================================================
#
# Initialization number:  6 	 ELBO:  -123446.17 	 N_iterations:  2
# =================================================
#
# Initialization number:  7 	 ELBO:  -92099.586 	 N_iterations:  3
# =================================================
#
# Initialization number:  8 	 ELBO:  -65274.895 	 N_iterations:  4
# =================================================
#
# Initialization number:  9 	 ELBO:  -97055.75 	 N_iterations:  4
# =================================================
#
# Initialization number:  10 	 ELBO:  -130767.98 	 N_iterations:  2
# =================================================
#
# Initialization number:  11 	 ELBO:  -85241.35 	 N_iterations:  4
# =================================================
#
# Initialization number:  12 	 ELBO:  -73005.26 	 N_iterations:  7
# =================================================
#
# Initialization number:  13 	 ELBO:  -124139.16 	 N_iterations:  2
# =================================================
#
# Initialization number:  14 	 ELBO:  -94792.18 	 N_iterations:  5
# =================================================
#
# Initialization number:  15 	 ELBO:  -101125.24 	 N_iterations:  6
# =================================================
#
# Initialization number:  16 	 ELBO:  -66692.36 	 N_iterations:  6
# =================================================
#
# Initialization number:  17 	 ELBO:  -67981.625 	 N_iterations:  3
# =================================================
#
# Initialization number:  18 	 ELBO:  -103172.19 	 N_iterations:  2
# =================================================
#
# Initialization number:  19 	 ELBO:  -88732.91 	 N_iterations:  5
# =================================================
#
# Initialization number:  20 	 ELBO:  -88288.31 	 N_iterations:  4
# =================================================
#
# Initialization number:  21 	 ELBO:  -61494.418 	 N_iterations:  4
# =================================================
#
# Initialization number:  22 	 ELBO:  -71973.625 	 N_iterations:  4
# =================================================
#
# Initialization number:  23 	 ELBO:  -100545.07 	 N_iterations:  3
# =================================================
#
# Initialization number:  24 	 ELBO:  -76002.57 	 N_iterations:  6
# =================================================
#
# Initialization number:  25 	 ELBO:  -100672.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  26 	 ELBO:  -97434.695 	 N_iterations:  4
# =================================================
#
# Initialization number:  27 	 ELBO:  -97272.83 	 N_iterations:  4
# =================================================
#
# Initialization number:  28 	 ELBO:  -89169.19 	 N_iterations:  3
# =================================================
#
# Initialization number:  29 	 ELBO:  -61254.684 	 N_iterations:  6
# =================================================
#
# Initialization number:  30 	 ELBO:  -117609.79 	 N_iterations:  3
# =================================================
#
# Initialization number:  31 	 ELBO:  -100832.77 	 N_iterations:  5
# =================================================
#
# Initialization number:  32 	 ELBO:  -124568.0 	 N_iterations:  3
# =================================================
#
# Initialization number:  33 	 ELBO:  -57972.17 	 N_iterations:  5
# =================================================
#
# Initialization number:  34 	 ELBO:  -101663.164 	 N_iterations:  4
# =================================================
#
# Initialization number:  35 	 ELBO:  -72020.07 	 N_iterations:  5
# =================================================
#
# Initialization number:  36 	 ELBO:  -78046.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  37 	 ELBO:  -102177.62 	 N_iterations:  2
# =================================================
#
# Initialization number:  38 	 ELBO:  -72211.02 	 N_iterations:  5
# =================================================
#
# Initialization number:  39 	 ELBO:  -97431.82 	 N_iterations:  4
# =================================================
#
# Initialization number:  40 	 ELBO:  -67935.08 	 N_iterations:  8
# =================================================
#
# Initialization number:  41 	 ELBO:  -93430.11 	 N_iterations:  3
# =================================================
#
# Initialization number:  42 	 ELBO:  -90905.58 	 N_iterations:  5
# =================================================
#
# Initialization number:  43 	 ELBO:  -97630.71 	 N_iterations:  5
# =================================================
#
# Initialization number:  44 	 ELBO:  -92771.19 	 N_iterations:  5
# =================================================
#
# Initialization number:  45 	 ELBO:  -81334.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  46 	 ELBO:  -60614.727 	 N_iterations:  6
# =================================================
#
# Initialization number:  47 	 ELBO:  -96777.82 	 N_iterations:  6
# =================================================
#
# Initialization number:  48 	 ELBO:  -123396.58 	 N_iterations:  3
# =================================================
#
# Initialization number:  49 	 ELBO:  -75629.85 	 N_iterations:  5
# =================================================
#
# Initialization number:  50 	 ELBO:  -94784.06 	 N_iterations:  4
# =================================================
#
# Initialization number:  51 	 ELBO:  -98441.96 	 N_iterations:  2
# =================================================
#
# Initialization number:  52 	 ELBO:  -101232.56 	 N_iterations:  5
# =================================================
#
# Initialization number:  53 	 ELBO:  -130583.9 	 N_iterations:  3
# =================================================
#
# Initialization number:  54 	 ELBO:  -100561.71 	 N_iterations:  2
# =================================================
#
# Initialization number:  55 	 ELBO:  -97739.266 	 N_iterations:  6
# =================================================
#
# Initialization number:  56 	 ELBO:  -123396.58 	 N_iterations:  4
# =================================================
#
# Initialization number:  57 	 ELBO:  -100394.55 	 N_iterations:  5
# =================================================
#
# Initialization number:  58 	 ELBO:  -89812.43 	 N_iterations:  2
# =================================================
#
# Initialization number:  59 	 ELBO:  -69064.88 	 N_iterations:  5
# =================================================
#
# Initialization number:  60 	 ELBO:  -103613.01 	 N_iterations:  6
# =================================================
#
# Initialization number:  61 	 ELBO:  -117725.02 	 N_iterations:  2
# =================================================
#
# Initialization number:  62 	 ELBO:  -93386.92 	 N_iterations:  5
# =================================================
#
# Initialization number:  63 	 ELBO:  -90035.516 	 N_iterations:  4
# =================================================
#
# Initialization number:  64 	 ELBO:  -98904.97 	 N_iterations:  5
# =================================================
#
# Initialization number:  65 	 ELBO:  -65758.9 	 N_iterations:  7
# =================================================
#
# Initialization number:  66 	 ELBO:  -109137.94 	 N_iterations:  4
# =================================================
#
# Initialization number:  67 	 ELBO:  -95057.4 	 N_iterations:  7
# =================================================
#
# Initialization number:  68 	 ELBO:  -48090.652 	 N_iterations:  7
# =================================================
#
# Initialization number:  69 	 ELBO:  -100093.01 	 N_iterations:  4
# =================================================
#
# Initialization number:  70 	 ELBO:  -73589.57 	 N_iterations:  5
# =================================================
#
# Initialization number:  71 	 ELBO:  -90575.92 	 N_iterations:  6
# =================================================
#
# Initialization number:  72 	 ELBO:  -91504.98 	 N_iterations:  3
# =================================================
#
# Initialization number:  73 	 ELBO:  -69468.28 	 N_iterations:  4
# =================================================
#
# Initialization number:  74 	 ELBO:  -76288.53 	 N_iterations:  6
# =================================================
#
# Initialization number:  75 	 ELBO:  -81428.87 	 N_iterations:  4
# =================================================
#
# Initialization number:  76 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  77 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  78 	 ELBO:  -82138.04 	 N_iterations:  6
# =================================================
#
# Initialization number:  79 	 ELBO:  -98391.86 	 N_iterations:  4
# =================================================
#
# Initialization number:  80 	 ELBO:  -77883.914 	 N_iterations:  6
# =================================================
#
# Initialization number:  81 	 ELBO:  -102576.38 	 N_iterations:  3
# =================================================
#
# Initialization number:  82 	 ELBO:  -65369.91 	 N_iterations:  10
# =================================================
#
# Initialization number:  83 	 ELBO:  -97253.95 	 N_iterations:  3
# =================================================
#
# Initialization number:  84 	 ELBO:  -110067.21 	 N_iterations:  5
# =================================================
#
# Initialization number:  85 	 ELBO:  -86376.484 	 N_iterations:  5
# =================================================
#
# Initialization number:  86 	 ELBO:  -101022.266 	 N_iterations:  2
# =================================================
#
# Initialization number:  87 	 ELBO:  -76254.22 	 N_iterations:  5
# =================================================
#
# Initialization number:  88 	 ELBO:  -60064.137 	 N_iterations:  5
# =================================================
#
# Initialization number:  89 	 ELBO:  -90845.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  90 	 ELBO:  -96048.03 	 N_iterations:  2
# =================================================
#
# Initialization number:  91 	 ELBO:  -78093.87 	 N_iterations:  6
# =================================================
#
# Initialization number:  92 	 ELBO:  -94676.055 	 N_iterations:  5
# =================================================
#
# Initialization number:  93 	 ELBO:  -85397.73 	 N_iterations:  10
# =================================================
#
# Initialization number:  94 	 ELBO:  -95100.086 	 N_iterations:  5
# =================================================
#
# Initialization number:  95 	 ELBO:  -100452.54 	 N_iterations:  6
# =================================================
#
# Initialization number:  96 	 ELBO:  -95588.38 	 N_iterations:  4
# =================================================
#
# Initialization number:  97 	 ELBO:  -54463.04 	 N_iterations:  7
# =================================================
#
# Initialization number:  98 	 ELBO:  -97465.6 	 N_iterations:  5
# =================================================
#
# Initialization number:  99 	 ELBO:  -95242.62 	 N_iterations:  4
# =================================================
#
# Initialization number:  100 	 ELBO:  -74653.516 	 N_iterations:  3
# =================================================
#
# Best initialization at  2  	 ELBO:  -29953.46
#
#
# Initialization number:  1 	 ELBO:  -92477.2 	 N_iterations:  3
# =================================================
#
# Initialization number:  2 	 ELBO:  -29953.46 	 N_iterations:  2
# =================================================
#
# Initialization number:  3 	 ELBO:  -104458.195 	 N_iterations:  2
# =================================================
#
# Initialization number:  4 	 ELBO:  -65758.9 	 N_iterations:  9
# =================================================
#
# Initialization number:  5 	 ELBO:  -100805.96 	 N_iterations:  4
# =================================================
#
# Initialization number:  6 	 ELBO:  -123446.17 	 N_iterations:  2
# =================================================
#
# Initialization number:  7 	 ELBO:  -92099.586 	 N_iterations:  3
# =================================================
#
# Initialization number:  8 	 ELBO:  -65274.895 	 N_iterations:  4
# =================================================
#
# Initialization number:  9 	 ELBO:  -97055.75 	 N_iterations:  4
# =================================================
#
# Initialization number:  10 	 ELBO:  -130767.98 	 N_iterations:  2
# =================================================
#
# Initialization number:  11 	 ELBO:  -85241.35 	 N_iterations:  4
# =================================================
#
# Initialization number:  12 	 ELBO:  -73005.26 	 N_iterations:  7
# =================================================
#
# Initialization number:  13 	 ELBO:  -124139.16 	 N_iterations:  2
# =================================================
#
# Initialization number:  14 	 ELBO:  -94792.18 	 N_iterations:  5
# =================================================
#
# Initialization number:  15 	 ELBO:  -101125.24 	 N_iterations:  6
# =================================================
#
# Initialization number:  16 	 ELBO:  -66692.36 	 N_iterations:  6
# =================================================
#
# Initialization number:  17 	 ELBO:  -67981.625 	 N_iterations:  3
# =================================================
#
# Initialization number:  18 	 ELBO:  -103172.19 	 N_iterations:  2
# =================================================
#
# Initialization number:  19 	 ELBO:  -88732.91 	 N_iterations:  5
# =================================================
#
# Initialization number:  20 	 ELBO:  -88288.31 	 N_iterations:  4
# =================================================
#
# Initialization number:  21 	 ELBO:  -61494.418 	 N_iterations:  4
# =================================================
#
# Initialization number:  22 	 ELBO:  -71973.625 	 N_iterations:  4
# =================================================
#
# Initialization number:  23 	 ELBO:  -100545.07 	 N_iterations:  3
# =================================================
#
# Initialization number:  24 	 ELBO:  -76002.57 	 N_iterations:  6
# =================================================
#
# Initialization number:  25 	 ELBO:  -100672.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  26 	 ELBO:  -97434.695 	 N_iterations:  4
# =================================================
#
# Initialization number:  27 	 ELBO:  -97272.83 	 N_iterations:  4
# =================================================
#
# Initialization number:  28 	 ELBO:  -89169.19 	 N_iterations:  3
# =================================================
#
# Initialization number:  29 	 ELBO:  -61254.684 	 N_iterations:  6
# =================================================
#
# Initialization number:  30 	 ELBO:  -117609.79 	 N_iterations:  3
# =================================================
#
# Initialization number:  31 	 ELBO:  -100832.77 	 N_iterations:  5
# =================================================
#
# Initialization number:  32 	 ELBO:  -124568.0 	 N_iterations:  3
# =================================================
#
# Initialization number:  33 	 ELBO:  -57972.17 	 N_iterations:  5
# =================================================
#
# Initialization number:  34 	 ELBO:  -101663.164 	 N_iterations:  4
# =================================================
#
# Initialization number:  35 	 ELBO:  -72020.07 	 N_iterations:  5
# =================================================
#
# Initialization number:  36 	 ELBO:  -78046.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  37 	 ELBO:  -102177.62 	 N_iterations:  2
# =================================================
#
# Initialization number:  38 	 ELBO:  -72211.02 	 N_iterations:  5
# =================================================
#
# Initialization number:  39 	 ELBO:  -97431.82 	 N_iterations:  4
# =================================================
#
# Initialization number:  40 	 ELBO:  -67935.08 	 N_iterations:  8
# =================================================
#
# Initialization number:  41 	 ELBO:  -93430.11 	 N_iterations:  3
# =================================================
#
# Initialization number:  42 	 ELBO:  -90905.58 	 N_iterations:  5
# =================================================
#
# Initialization number:  43 	 ELBO:  -97630.71 	 N_iterations:  5
# =================================================
#
# Initialization number:  44 	 ELBO:  -92771.19 	 N_iterations:  5
# =================================================
#
# Initialization number:  45 	 ELBO:  -81334.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  46 	 ELBO:  -60614.727 	 N_iterations:  6
# =================================================
#
# Initialization number:  47 	 ELBO:  -96777.82 	 N_iterations:  6
# =================================================
#
# Initialization number:  48 	 ELBO:  -123396.58 	 N_iterations:  3
# =================================================
#
# Initialization number:  49 	 ELBO:  -75629.85 	 N_iterations:  5
# =================================================
#
# Initialization number:  50 	 ELBO:  -94784.06 	 N_iterations:  4
# =================================================
#
# Initialization number:  51 	 ELBO:  -98441.96 	 N_iterations:  2
# =================================================
#
# Initialization number:  52 	 ELBO:  -101232.56 	 N_iterations:  5
# =================================================
#
# Initialization number:  53 	 ELBO:  -130583.9 	 N_iterations:  3
# =================================================
#
# Initialization number:  54 	 ELBO:  -100561.71 	 N_iterations:  2
# =================================================
#
# Initialization number:  55 	 ELBO:  -97739.266 	 N_iterations:  6
# =================================================
#
# Initialization number:  56 	 ELBO:  -123396.58 	 N_iterations:  4
# =================================================
#
# Initialization number:  57 	 ELBO:  -100394.55 	 N_iterations:  5
# =================================================
#
# Initialization number:  58 	 ELBO:  -89812.43 	 N_iterations:  2
# =================================================
#
# Initialization number:  59 	 ELBO:  -69064.88 	 N_iterations:  5
# =================================================
#
# Initialization number:  60 	 ELBO:  -103613.01 	 N_iterations:  6
# =================================================
#
# Initialization number:  61 	 ELBO:  -117725.02 	 N_iterations:  2
# =================================================
#
# Initialization number:  62 	 ELBO:  -93386.92 	 N_iterations:  5
# =================================================
#
# Initialization number:  63 	 ELBO:  -90035.516 	 N_iterations:  4
# =================================================
#
# Initialization number:  64 	 ELBO:  -98904.97 	 N_iterations:  5
# =================================================
#
# Initialization number:  65 	 ELBO:  -65758.9 	 N_iterations:  7
# =================================================
#
# Initialization number:  66 	 ELBO:  -109137.94 	 N_iterations:  4
# =================================================
#
# Initialization number:  67 	 ELBO:  -95057.4 	 N_iterations:  7
# =================================================
#
# Initialization number:  68 	 ELBO:  -48090.652 	 N_iterations:  7
# =================================================
#
# Initialization number:  69 	 ELBO:  -100093.01 	 N_iterations:  4
# =================================================
#
# Initialization number:  70 	 ELBO:  -73589.57 	 N_iterations:  5
# =================================================
#
# Initialization number:  71 	 ELBO:  -90575.92 	 N_iterations:  6
# =================================================
#
# Initialization number:  72 	 ELBO:  -91504.98 	 N_iterations:  3
# =================================================
#
# Initialization number:  73 	 ELBO:  -69468.28 	 N_iterations:  4
# =================================================
#
# Initialization number:  74 	 ELBO:  -76288.53 	 N_iterations:  6
# =================================================
#
# Initialization number:  75 	 ELBO:  -81428.87 	 N_iterations:  4
# =================================================
#
# Initialization number:  76 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  77 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  78 	 ELBO:  -82138.04 	 N_iterations:  6
# =================================================
#
# Initialization number:  79 	 ELBO:  -98391.86 	 N_iterations:  4
# =================================================
#
# Initialization number:  80 	 ELBO:  -77883.914 	 N_iterations:  6
# =================================================
#
# Initialization number:  81 	 ELBO:  -102576.38 	 N_iterations:  3
# =================================================
#
# Initialization number:  82 	 ELBO:  -65369.91 	 N_iterations:  10
# =================================================
#
# Initialization number:  83 	 ELBO:  -97253.95 	 N_iterations:  3
# =================================================
#
# Initialization number:  84 	 ELBO:  -110067.21 	 N_iterations:  5
# =================================================
#
# Initialization number:  85 	 ELBO:  -86376.484 	 N_iterations:  5
# =================================================
#
# Initialization number:  86 	 ELBO:  -101022.266 	 N_iterations:  2
# =================================================
#
# Initialization number:  87 	 ELBO:  -76254.22 	 N_iterations:  5
# =================================================
#
# Initialization number:  88 	 ELBO:  -60064.137 	 N_iterations:  5
# =================================================
#
# Initialization number:  89 	 ELBO:  -90845.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  90 	 ELBO:  -96048.03 	 N_iterations:  2
# =================================================
#
# Initialization number:  91 	 ELBO:  -78093.87 	 N_iterations:  6
# =================================================
#
# Initialization number:  92 	 ELBO:  -94676.055 	 N_iterations:  5
# =================================================
#
# Initialization number:  93 	 ELBO:  -85397.73 	 N_iterations:  10
# =================================================
#
# Initialization number:  94 	 ELBO:  -95100.086 	 N_iterations:  5
# =================================================
#
# Initialization number:  95 	 ELBO:  -100452.54 	 N_iterations:  6
# =================================================
#
# Initialization number:  96 	 ELBO:  -95588.38 	 N_iterations:  4
# =================================================
#
# Initialization number:  97 	 ELBO:  -54463.04 	 N_iterations:  7
# =================================================
#
# Initialization number:  98 	 ELBO:  -97465.6 	 N_iterations:  5
# =================================================
#
# Initialization number:  99 	 ELBO:  -95242.62 	 N_iterations:  4
# =================================================
#
# Initialization number:  100 	 ELBO:  -74653.516 	 N_iterations:  3
# =================================================
#
# Best initialization at  2  	 ELBO:  -29953.46
#
#
# Initialization number:  1 	 ELBO:  -92477.2 	 N_iterations:  3
# =================================================
#
# Initialization number:  2 	 ELBO:  -29953.46 	 N_iterations:  2
# =================================================
#
# Initialization number:  3 	 ELBO:  -104458.195 	 N_iterations:  2
# =================================================
#
# Initialization number:  4 	 ELBO:  -65758.9 	 N_iterations:  9
# =================================================
#
# Initialization number:  5 	 ELBO:  -100805.96 	 N_iterations:  4
# =================================================
#
# Initialization number:  6 	 ELBO:  -123446.17 	 N_iterations:  2
# =================================================
#
# Initialization number:  7 	 ELBO:  -92099.586 	 N_iterations:  3
# =================================================
#
# Initialization number:  8 	 ELBO:  -65274.895 	 N_iterations:  4
# =================================================
#
# Initialization number:  9 	 ELBO:  -97055.75 	 N_iterations:  4
# =================================================
#
# Initialization number:  10 	 ELBO:  -130767.98 	 N_iterations:  2
# =================================================
#
# Initialization number:  11 	 ELBO:  -85241.35 	 N_iterations:  4
# =================================================
#
# Initialization number:  12 	 ELBO:  -73005.26 	 N_iterations:  7
# =================================================
#
# Initialization number:  13 	 ELBO:  -124139.16 	 N_iterations:  2
# =================================================
#
# Initialization number:  14 	 ELBO:  -94792.18 	 N_iterations:  5
# =================================================
#
# Initialization number:  15 	 ELBO:  -101125.24 	 N_iterations:  6
# =================================================
#
# Initialization number:  16 	 ELBO:  -66692.36 	 N_iterations:  6
# =================================================
#
# Initialization number:  17 	 ELBO:  -67981.625 	 N_iterations:  3
# =================================================
#
# Initialization number:  18 	 ELBO:  -103172.19 	 N_iterations:  2
# =================================================
#
# Initialization number:  19 	 ELBO:  -88732.91 	 N_iterations:  5
# =================================================
#
# Initialization number:  20 	 ELBO:  -88288.31 	 N_iterations:  4
# =================================================
#
# Initialization number:  21 	 ELBO:  -61494.418 	 N_iterations:  4
# =================================================
#
# Initialization number:  22 	 ELBO:  -71973.625 	 N_iterations:  4
# =================================================
#
# Initialization number:  23 	 ELBO:  -100545.07 	 N_iterations:  3
# =================================================
#
# Initialization number:  24 	 ELBO:  -76002.57 	 N_iterations:  6
# =================================================
#
# Initialization number:  25 	 ELBO:  -100672.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  26 	 ELBO:  -97434.695 	 N_iterations:  4
# =================================================
#
# Initialization number:  27 	 ELBO:  -97272.83 	 N_iterations:  4
# =================================================
#
# Initialization number:  28 	 ELBO:  -89169.19 	 N_iterations:  3
# =================================================
#
# Initialization number:  29 	 ELBO:  -61254.684 	 N_iterations:  6
# =================================================
#
# Initialization number:  30 	 ELBO:  -117609.79 	 N_iterations:  3
# =================================================
#
# Initialization number:  31 	 ELBO:  -100832.77 	 N_iterations:  5
# =================================================
#
# Initialization number:  32 	 ELBO:  -124568.0 	 N_iterations:  3
# =================================================
#
# Initialization number:  33 	 ELBO:  -57972.17 	 N_iterations:  5
# =================================================
#
# Initialization number:  34 	 ELBO:  -101663.164 	 N_iterations:  4
# =================================================
#
# Initialization number:  35 	 ELBO:  -72020.07 	 N_iterations:  5
# =================================================
#
# Initialization number:  36 	 ELBO:  -78046.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  37 	 ELBO:  -102177.62 	 N_iterations:  2
# =================================================
#
# Initialization number:  38 	 ELBO:  -72211.02 	 N_iterations:  5
# =================================================
#
# Initialization number:  39 	 ELBO:  -97431.82 	 N_iterations:  4
# =================================================
#
# Initialization number:  40 	 ELBO:  -67935.08 	 N_iterations:  8
# =================================================
#
# Initialization number:  41 	 ELBO:  -93430.11 	 N_iterations:  3
# =================================================
#
# Initialization number:  42 	 ELBO:  -90905.58 	 N_iterations:  5
# =================================================
#
# Initialization number:  43 	 ELBO:  -97630.71 	 N_iterations:  5
# =================================================
#
# Initialization number:  44 	 ELBO:  -92771.19 	 N_iterations:  5
# =================================================
#
# Initialization number:  45 	 ELBO:  -81334.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  46 	 ELBO:  -60614.727 	 N_iterations:  6
# =================================================
#
# Initialization number:  47 	 ELBO:  -96777.82 	 N_iterations:  6
# =================================================
#
# Initialization number:  48 	 ELBO:  -123396.58 	 N_iterations:  3
# =================================================
#
# Initialization number:  49 	 ELBO:  -75629.85 	 N_iterations:  5
# =================================================
#
# Initialization number:  50 	 ELBO:  -94784.06 	 N_iterations:  4
# =================================================
#
# Initialization number:  51 	 ELBO:  -98441.96 	 N_iterations:  2
# =================================================
#
# Initialization number:  52 	 ELBO:  -101232.56 	 N_iterations:  5
# =================================================
#
# Initialization number:  53 	 ELBO:  -130583.9 	 N_iterations:  3
# =================================================
#
# Initialization number:  54 	 ELBO:  -100561.71 	 N_iterations:  2
# =================================================
#
# Initialization number:  55 	 ELBO:  -97739.266 	 N_iterations:  6
# =================================================
#
# Initialization number:  56 	 ELBO:  -123396.58 	 N_iterations:  4
# =================================================
#
# Initialization number:  57 	 ELBO:  -100394.55 	 N_iterations:  5
# =================================================
#
# Initialization number:  58 	 ELBO:  -89812.43 	 N_iterations:  2
# =================================================
#
# Initialization number:  59 	 ELBO:  -69064.88 	 N_iterations:  5
# =================================================
#
# Initialization number:  60 	 ELBO:  -103613.01 	 N_iterations:  6
# =================================================
#
# Initialization number:  61 	 ELBO:  -117725.02 	 N_iterations:  2
# =================================================
#
# Initialization number:  62 	 ELBO:  -93386.92 	 N_iterations:  5
# =================================================
#
# Initialization number:  63 	 ELBO:  -90035.516 	 N_iterations:  4
# =================================================
#
# Initialization number:  64 	 ELBO:  -98904.97 	 N_iterations:  5
# =================================================
#
# Initialization number:  65 	 ELBO:  -65758.9 	 N_iterations:  7
# =================================================
#
# Initialization number:  66 	 ELBO:  -109137.94 	 N_iterations:  4
# =================================================
#
# Initialization number:  67 	 ELBO:  -95057.4 	 N_iterations:  7
# =================================================
#
# Initialization number:  68 	 ELBO:  -48090.652 	 N_iterations:  7
# =================================================
#
# Initialization number:  69 	 ELBO:  -100093.01 	 N_iterations:  4
# =================================================
#
# Initialization number:  70 	 ELBO:  -73589.57 	 N_iterations:  5
# =================================================
#
# Initialization number:  71 	 ELBO:  -90575.92 	 N_iterations:  6
# =================================================
#
# Initialization number:  72 	 ELBO:  -91504.98 	 N_iterations:  3
# =================================================
#
# Initialization number:  73 	 ELBO:  -69468.28 	 N_iterations:  4
# =================================================
#
# Initialization number:  74 	 ELBO:  -76288.53 	 N_iterations:  6
# =================================================
#
# Initialization number:  75 	 ELBO:  -81428.87 	 N_iterations:  4
# =================================================
#
# Initialization number:  76 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  77 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  78 	 ELBO:  -82138.04 	 N_iterations:  6
# =================================================
#
# Initialization number:  79 	 ELBO:  -98391.86 	 N_iterations:  4
# =================================================
#
# Initialization number:  80 	 ELBO:  -77883.914 	 N_iterations:  6
# =================================================
#
# Initialization number:  81 	 ELBO:  -102576.38 	 N_iterations:  3
# =================================================
#
# Initialization number:  82 	 ELBO:  -65369.91 	 N_iterations:  10
# =================================================
#
# Initialization number:  83 	 ELBO:  -97253.95 	 N_iterations:  3
# =================================================
#
# Initialization number:  84 	 ELBO:  -110067.21 	 N_iterations:  5
# =================================================
#
# Initialization number:  85 	 ELBO:  -86376.484 	 N_iterations:  5
# =================================================
#
# Initialization number:  86 	 ELBO:  -101022.266 	 N_iterations:  2
# =================================================
#
# Initialization number:  87 	 ELBO:  -76254.22 	 N_iterations:  5
# =================================================
#
# Initialization number:  88 	 ELBO:  -60064.137 	 N_iterations:  5
# =================================================
#
# Initialization number:  89 	 ELBO:  -90845.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  90 	 ELBO:  -96048.03 	 N_iterations:  2
# =================================================
#
# Initialization number:  91 	 ELBO:  -78093.87 	 N_iterations:  6
# =================================================
#
# Initialization number:  92 	 ELBO:  -94676.055 	 N_iterations:  5
# =================================================
#
# Initialization number:  93 	 ELBO:  -85397.73 	 N_iterations:  10
# =================================================
#
# Initialization number:  94 	 ELBO:  -95100.086 	 N_iterations:  5
# =================================================
#
# Initialization number:  95 	 ELBO:  -100452.54 	 N_iterations:  6
# =================================================
#
# Initialization number:  96 	 ELBO:  -95588.38 	 N_iterations:  4
# =================================================
#
# Initialization number:  97 	 ELBO:  -54463.04 	 N_iterations:  7
# =================================================
#
# Initialization number:  98 	 ELBO:  -97465.6 	 N_iterations:  5
# =================================================
#
# Initialization number:  99 	 ELBO:  -95242.62 	 N_iterations:  4
# =================================================
#
# Initialization number:  100 	 ELBO:  -74653.516 	 N_iterations:  3
# =================================================
#
# Best initialization at  2  	 ELBO:  -29953.46
#
#
# Initialization number:  1 	 ELBO:  -92477.2 	 N_iterations:  3
# =================================================
#
# Initialization number:  2 	 ELBO:  -29953.46 	 N_iterations:  2
# =================================================
#
# Initialization number:  3 	 ELBO:  -104458.195 	 N_iterations:  2
# =================================================
#
# Initialization number:  4 	 ELBO:  -65758.9 	 N_iterations:  9
# =================================================
#
# Initialization number:  5 	 ELBO:  -100805.96 	 N_iterations:  4
# =================================================
#
# Initialization number:  6 	 ELBO:  -123446.17 	 N_iterations:  2
# =================================================
#
# Initialization number:  7 	 ELBO:  -92099.586 	 N_iterations:  3
# =================================================
#
# Initialization number:  8 	 ELBO:  -65274.895 	 N_iterations:  4
# =================================================
#
# Initialization number:  9 	 ELBO:  -97055.75 	 N_iterations:  4
# =================================================
#
# Initialization number:  10 	 ELBO:  -130767.98 	 N_iterations:  2
# =================================================
#
# Initialization number:  11 	 ELBO:  -85241.35 	 N_iterations:  4
# ...
#
# Initialization number:  65 	 ELBO:  -65758.9 	 N_iterations:  7
# =================================================
#
# Initialization number:  66 	 ELBO:  -109137.94 	 N_iterations:  4
# =================================================
#
# Initialization number:  67 	 ELBO:  -95057.4 	 N_iterations:  7
# =================================================
#
# Initialization number:  68 	 ELBO:  -48090.652 	 N_iterations:  7
# =================================================
#
# Initialization number:  69 	 ELBO:  -100093.01 	 N_iterations:  4
# =================================================
#
# Initialization number:  70 	 ELBO:  -73589.57 	 N_iterations:  5
# =================================================
#
# Initialization number:  71 	 ELBO:  -90575.92 	 N_iterations:  6
# =================================================
#
# Initialization number:  72 	 ELBO:  -91504.98 	 N_iterations:  3
# =================================================
#
# Initialization number:  73 	 ELBO:  -69468.28 	 N_iterations:  4
# =================================================
#
# Initialization number:  74 	 ELBO:  -76288.53 	 N_iterations:  6
# =================================================
#
# Initialization number:  75 	 ELBO:  -81428.87 	 N_iterations:  4
# =================================================
#
# Initialization number:  76 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  77 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  78 	 ELBO:  -82138.04 	 N_iterations:  6
# =================================================
#
# Initialization number:  79 	 ELBO:  -98391.86 	 N_iterations:  4
# =================================================
#
# Initialization number:  80 	 ELBO:  -77883.914 	 N_iterations:  6
# =================================================
#
# Initialization number:  81 	 ELBO:  -102576.38 	 N_iterations:  3
# =================================================
#
# Initialization number:  82 	 ELBO:  -65369.91 	 N_iterations:  10
# =================================================
#
# Initialization number:  83 	 ELBO:  -97253.95 	 N_iterations:  3
# =================================================
#
# Initialization number:  84 	 ELBO:  -110067.21 	 N_iterations:  5
# =================================================
#
# Initialization number:  85 	 ELBO:  -86376.484 	 N_iterations:  5
# =================================================
#
# Initialization number:  86 	 ELBO:  -101022.266 	 N_iterations:  2
# =================================================
#
# Initialization number:  87 	 ELBO:  -76254.22 	 N_iterations:  5
# =================================================
#
# Initialization number:  88 	 ELBO:  -60064.137 	 N_iterations:  5
# =================================================
#
# Initialization number:  89 	 ELBO:  -90845.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  90 	 ELBO:  -96048.03 	 N_iterations:  2
# =================================================
#
# Initialization number:  91 	 ELBO:  -78093.87 	 N_iterations:  6
# =================================================
#
# Initialization number:  92 	 ELBO:  -94676.055 	 N_iterations:  5
# =================================================
#
# Initialization number:  93 	 ELBO:  -85397.73 	 N_iterations:  10
# =================================================
#
# Initialization number:  94 	 ELBO:  -95100.086 	 N_iterations:  5
# =================================================
#
# Initialization number:  95 	 ELBO:  -100452.54 	 N_iterations:  6
# =================================================
#
# Initialization number:  96 	 ELBO:  -95588.38 	 N_iterations:  4
# =================================================
#
# Initialization number:  97 	 ELBO:  -54463.04 	 N_iterations:  7
# =================================================
#
# Initialization number:  98 	 ELBO:  -97465.6 	 N_iterations:  5
# =================================================
#
# Initialization number:  99 	 ELBO:  -95242.62 	 N_iterations:  4
# =================================================
#
# Initialization number:  100 	 ELBO:  -74653.516 	 N_iterations:  3
# =================================================
#
# Best initialization at  2  	 ELBO:  -29953.46
#
#
# Initialization number:  1 	 ELBO:  -92477.2 	 N_iterations:  3
# =================================================
#
# Initialization number:  2 	 ELBO:  -29953.46 	 N_iterations:  2
# =================================================
#
# Initialization number:  3 	 ELBO:  -104458.195 	 N_iterations:  2
# =================================================
#
# Initialization number:  4 	 ELBO:  -65758.9 	 N_iterations:  9
# =================================================
#
# Initialization number:  5 	 ELBO:  -100805.96 	 N_iterations:  4
# =================================================
#
# Initialization number:  6 	 ELBO:  -123446.17 	 N_iterations:  2
# =================================================
#
# Initialization number:  7 	 ELBO:  -92099.586 	 N_iterations:  3
# =================================================
#
# Initialization number:  8 	 ELBO:  -65274.895 	 N_iterations:  4
# =================================================
#
# Initialization number:  9 	 ELBO:  -97055.75 	 N_iterations:  4
# =================================================
#
# Initialization number:  10 	 ELBO:  -130767.98 	 N_iterations:  2
# =================================================
#
# Initialization number:  11 	 ELBO:  -85241.35 	 N_iterations:  4
# =================================================
#
# Initialization number:  12 	 ELBO:  -73005.26 	 N_iterations:  7
# =================================================
#
# Initialization number:  13 	 ELBO:  -124139.16 	 N_iterations:  2
# =================================================
#
# Initialization number:  14 	 ELBO:  -94792.18 	 N_iterations:  5
# =================================================
#
# Initialization number:  15 	 ELBO:  -101125.24 	 N_iterations:  6
# =================================================
#
# Initialization number:  16 	 ELBO:  -66692.36 	 N_iterations:  6
# =================================================
#
# Initialization number:  17 	 ELBO:  -67981.625 	 N_iterations:  3
# =================================================
#
# Initialization number:  18 	 ELBO:  -103172.19 	 N_iterations:  2
# =================================================
#
# Initialization number:  19 	 ELBO:  -88732.91 	 N_iterations:  5
# =================================================
#
# Initialization number:  20 	 ELBO:  -88288.31 	 N_iterations:  4
# =================================================
#
# Initialization number:  21 	 ELBO:  -61494.418 	 N_iterations:  4
# =================================================
#
# Initialization number:  22 	 ELBO:  -71973.625 	 N_iterations:  4
# =================================================
#
# Initialization number:  23 	 ELBO:  -100545.07 	 N_iterations:  3
# =================================================
#
# Initialization number:  24 	 ELBO:  -76002.57 	 N_iterations:  6
# =================================================
#
# Initialization number:  25 	 ELBO:  -100672.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  26 	 ELBO:  -97434.695 	 N_iterations:  4
# =================================================
#
# Initialization number:  27 	 ELBO:  -97272.83 	 N_iterations:  4
# =================================================
#
# Initialization number:  28 	 ELBO:  -89169.19 	 N_iterations:  3
# =================================================
#
# Initialization number:  29 	 ELBO:  -61254.684 	 N_iterations:  6
# =================================================
#
# Initialization number:  30 	 ELBO:  -117609.79 	 N_iterations:  3
# =================================================
#
# Initialization number:  31 	 ELBO:  -100832.77 	 N_iterations:  5
# =================================================
#
# Initialization number:  32 	 ELBO:  -124568.0 	 N_iterations:  3
# =================================================
#
# Initialization number:  33 	 ELBO:  -57972.17 	 N_iterations:  5
# =================================================
#
# Initialization number:  34 	 ELBO:  -101663.164 	 N_iterations:  4
# =================================================
#
# Initialization number:  35 	 ELBO:  -72020.07 	 N_iterations:  5
# =================================================
#
# Initialization number:  36 	 ELBO:  -78046.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  37 	 ELBO:  -102177.62 	 N_iterations:  2
# =================================================
#
# Initialization number:  38 	 ELBO:  -72211.02 	 N_iterations:  5
# =================================================
#
# Initialization number:  39 	 ELBO:  -97431.82 	 N_iterations:  4
# =================================================
#
# Initialization number:  40 	 ELBO:  -67935.08 	 N_iterations:  8
# =================================================
#
# Initialization number:  41 	 ELBO:  -93430.11 	 N_iterations:  3
# =================================================
#
# Initialization number:  42 	 ELBO:  -90905.58 	 N_iterations:  5
# =================================================
#
# Initialization number:  43 	 ELBO:  -97630.71 	 N_iterations:  5
# =================================================
#
# Initialization number:  44 	 ELBO:  -92771.19 	 N_iterations:  5
# =================================================
#
# Initialization number:  45 	 ELBO:  -81334.29 	 N_iterations:  4
# =================================================
#
# Initialization number:  46 	 ELBO:  -60614.727 	 N_iterations:  6
# =================================================
#
# Initialization number:  47 	 ELBO:  -96777.82 	 N_iterations:  6
# =================================================
#
# Initialization number:  48 	 ELBO:  -123396.58 	 N_iterations:  3
# =================================================
#
# Initialization number:  49 	 ELBO:  -75629.85 	 N_iterations:  5
# =================================================
#
# Initialization number:  50 	 ELBO:  -94784.06 	 N_iterations:  4
# =================================================
#
# Initialization number:  51 	 ELBO:  -98441.96 	 N_iterations:  2
# =================================================
#
# Initialization number:  52 	 ELBO:  -101232.56 	 N_iterations:  5
# =================================================
#
# Initialization number:  53 	 ELBO:  -130583.9 	 N_iterations:  3
# =================================================
#
# Initialization number:  54 	 ELBO:  -100561.71 	 N_iterations:  2
# =================================================
#
# Initialization number:  55 	 ELBO:  -97739.266 	 N_iterations:  6
# =================================================
#
# Initialization number:  56 	 ELBO:  -123396.58 	 N_iterations:  4
# =================================================
#
# Initialization number:  57 	 ELBO:  -100394.55 	 N_iterations:  5
# =================================================
#
# Initialization number:  58 	 ELBO:  -89812.43 	 N_iterations:  2
# =================================================
#
# Initialization number:  59 	 ELBO:  -69064.88 	 N_iterations:  5
# =================================================
#
# Initialization number:  60 	 ELBO:  -103613.01 	 N_iterations:  6
# =================================================
#
# Initialization number:  61 	 ELBO:  -117725.02 	 N_iterations:  2
# =================================================
#
# Initialization number:  62 	 ELBO:  -93386.92 	 N_iterations:  5
# =================================================
#
# Initialization number:  63 	 ELBO:  -90035.516 	 N_iterations:  4
# =================================================
#
# Initialization number:  64 	 ELBO:  -98904.97 	 N_iterations:  5
# =================================================
#
# Initialization number:  65 	 ELBO:  -65758.9 	 N_iterations:  7
# =================================================
#
# Initialization number:  66 	 ELBO:  -109137.94 	 N_iterations:  4
# =================================================
#
# Initialization number:  67 	 ELBO:  -95057.4 	 N_iterations:  7
# =================================================
#
# Initialization number:  68 	 ELBO:  -48090.652 	 N_iterations:  7
# =================================================
#
# Initialization number:  69 	 ELBO:  -100093.01 	 N_iterations:  4
# =================================================
#
# Initialization number:  70 	 ELBO:  -73589.57 	 N_iterations:  5
# =================================================
#
# Initialization number:  71 	 ELBO:  -90575.92 	 N_iterations:  6
# =================================================
#
# Initialization number:  72 	 ELBO:  -91504.98 	 N_iterations:  3
# =================================================
#
# Initialization number:  73 	 ELBO:  -69468.28 	 N_iterations:  4
# =================================================
#
# Initialization number:  74 	 ELBO:  -76288.53 	 N_iterations:  6
# =================================================
#
# Initialization number:  75 	 ELBO:  -81428.87 	 N_iterations:  4
# =================================================
#
# Initialization number:  76 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  77 	 ELBO:  -123396.59 	 N_iterations:  4
# =================================================
#
# Initialization number:  78 	 ELBO:  -82138.04 	 N_iterations:  6
# =================================================
#
# Initialization number:  79 	 ELBO:  -98391.86 	 N_iterations:  4
# =================================================
#
# Initialization number:  80 	 ELBO:  -77883.914 	 N_iterations:  6
# =================================================
#
# Initialization number:  81 	 ELBO:  -102576.38 	 N_iterations:  3
# =================================================
#
# Initialization number:  82 	 ELBO:  -65369.91 	 N_iterations:  10
# =================================================
#
# Initialization number:  83 	 ELBO:  -97253.95 	 N_iterations:  3
# =================================================
#
# Initialization number:  84 	 ELBO:  -110067.21 	 N_iterations:  5
# =================================================
#
# Initialization number:  85 	 ELBO:  -86376.484 	 N_iterations:  5
# =================================================
#
# Initialization number:  86 	 ELBO:  -101022.266 	 N_iterations:  2
# =================================================
#
# Initialization number:  87 	 ELBO:  -76254.22 	 N_iterations:  5
# =================================================
#
# Initialization number:  88 	 ELBO:  -60064.137 	 N_iterations:  5
# =================================================
#
# Initialization number:  89 	 ELBO:  -90845.7 	 N_iterations:  4
# =================================================
#
# Initialization number:  90 	 ELBO:  -96048.03 	 N_iterations:  2
# =================================================
#
# Initialization number:  91 	 ELBO:  -78093.87 	 N_iterations:  6
# =================================================
#
# Initialization number:  92 	 ELBO:  -94676.055 	 N_iterations:  5
# =================================================
#
# Initialization number:  93 	 ELBO:  -85397.73 	 N_iterations:  10
# =================================================
#
# Initialization number:  94 	 ELBO:  -95100.086 	 N_iterations:  5
# =================================================
#
# Initialization number:  95 	 ELBO:  -100452.54 	 N_iterations:  6
# =================================================
#
# Initialization number:  96 	 ELBO:  -95588.38 	 N_iterations:  4
# =================================================
#
# Initialization number:  97 	 ELBO:  -54463.04 	 N_iterations:  7
# =================================================
#
# Initialization number:  98 	 ELBO:  -97465.6 	 N_iterations:  5
# =================================================
#
# Initialization number:  99 	 ELBO:  -95242.62 	 N_iterations:  4
# =================================================
#
# Initialization number:  100 	 ELBO:  -74653.516 	 N_iterations:  3
# =================================================
#
# Best initialization at  2  	 ELBO:  -29953.46
#
#
# 566 ms ± 69.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
n_cluster = np.sum(C, axis = 0)
m_post=1/(1+1/sigma**2)/np.matmul(n_cluster.reshape((K,1)),np.ones(shape=(1,d)))*np.matmul(C.T,X)
s2_post=1/(1+1/sigma**2)/n_cluster
error_m_s2,error_clust=error_measure(m_post,s2_post,C,m,s2,phi)
error_m_s2,error_clust
# Out:
# (Array(1.0398538e+09, dtype=float32), 0.18670844106458706)
