# %%
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random
import numpy as np
import jax
# !pip install mycolorpy

# %% [markdown]
# # Generazione Dati

# %%
from IPython.utils.sysinfo import num_cpus

# numero di cluster
K=5

# dimensione del campione
d=2

# numero di sample
N=1000

seed=2022
key = random.PRNGKey(seed)
# vectors of mean of clusters
sigma=5
mu=random.normal(key,(K,d))*sigma

# cluster assignment
key = random.PRNGKey(2)
c=random.categorical(key,(1/K)*jnp.ones(shape=(K,)),axis=0,shape=(N,))
C=np.zeros(shape=(N,K))
for i in range(N):
  C[i,c[i]]=1
C=jnp.array(C)

# Data
X=jnp.matmul(C,mu)+random.normal(key,(N,d))

# %%
import matplotlib.pyplot as plt

for i in range(K):
  plt.scatter(X[c==i,0],X[c==i,1])
plt.show()

# %% [markdown]
# # Variational Inference
#
# We construct the model for our VI algorithm, we stick to the notation of the paper. Our model is described by:
#
# \begin{align*}
#     \mu_k\ \mid x &\stackrel{\tiny\mbox{ind}}{\sim} \mathcal{N}_d\left(m_k, s^2_k\ \mathbb{I}_d\right) \qquad \qquad \ \ \  k=1,...,K\\
#     x_i \mid c_i,μ &\stackrel{\tiny\mbox{ind}}{\sim} \mathcal{N}_d\left(c^T_iμ, \ \mathbb{I}_d\ \right) \qquad  \qquad \ \ \ \  i=1,...,n \\
#     \mu_k &\stackrel{\tiny\mbox{iid}}{\sim}\mathcal{N}_d\left(0, \ \sigma^2\  \mathbb{I}_d\right) \qquad \qquad \ \ \ \   k=1,...,K\\
#     c_ i&\stackrel{\tiny\mbox{iid}}{\sim} Cat(\frac{1}{K},...,\frac{1}{K}) \qquad \qquad  i=1,...,n
# \end{align*}

# %% [markdown]
# Considering $q(c_i=k)$=$𝝋_{ik}$ we can define the variational update for the ith cluster assignment as
#
# \begin{align*}
#   𝜑_{ik}∝exp[\ \mathbb{E}[\mu_k;\ m_k,\ s_k^2]x_i-\mathbb{E}[\mu_k^2;\ m_k,\ s_k^2]/2\ ]
# \end{align*}
#
# Then we can define the updates for the variational density of the kth mixture component q($\mu_k$) in terms of variational mean and variance
#
#
# \begin{align*}
#     \hat{m_k}=\frac{\sum_{i}^{}𝝋_{ik}x_i}{\frac{1}{\sigma^2}+\sum_{i}^{}𝝋_{ik}} \qquad \qquad \hat{s_k}^2=\frac{1}{\frac{1}{\sigma^2}+\sum_{i}^{}𝝋_{ik}}
# \end{align*}
#
#
# VI can be considered as an optimization problem, so we need to define the function to be optimized, which is the ELBO.
# \begin{align*}
#     ELBO(\hat{m},\hat{s}^2,𝜑)=\sum_{k=1}^{K}\mathbb{E}[\log p(\mu_k);\ \hat{m_k},\ \hat{s_k}^2] \  +\\  \sum_{i=1}^{n}(\ \mathbb{E}[\log p(c_i);\ 𝜑_i]+\mathbb{E}[\log p(x_i|c_i,μ);\ 𝜑_i,\ \hat{m},\ \hat{s}^2]\ )\ + \  \\ - \sum_{i=1}^{n} \mathbb{E}[\log q(c_i;\ 𝜑_i)]- \sum_{k=1}^{K} \mathbb{E}[\log q(\mu_k;\ \hat{m_k},\ \hat{s_k}^2)]
# \end{align*}
#
# \\
# Considering $k=1,...,K$ and $i=1,...,n$

# %%
#def update_phi(data,phi,m,s2):
#  for i in jnp.arange(data.shape[0]):
#    for k in jnp.arange(phi.shape[1]):
#      phi[i,k]=jnp.exp(jnp.matmul(m[k,:],data[i,:].transpose())-(s2[k]+jnp.matmul(m[k,:],m[k,:].transpose()))/2) # non sono così sicuro della formula per mk^2
#    phi[i,:]=phi[i,:]/jnp.sum(phi[i,:])
#  return phi

def update_phi(data, phi, m, s2):
    updated_phi = jnp.zeros_like(phi)
    M=jnp.matmul(m,m.T)
    log_likelihood = jnp.matmul(data,m.T) - 0.5 * jnp.matmul(jnp.ones(shape=(N,1)),(s2.T + jnp.resize(jnp.diag(M),(K,1)).T))
    updated_phi = jnp.exp(log_likelihood)

    updated_phi /= jnp.sum(updated_phi,axis=1,keepdims=True)
    return updated_phi

update_phi_jit=jit(update_phi)


def update_mean_and_variance(data,phi,sigma):
  K=phi.shape[1]
  d=data.shape[1]
  N=data.shape[0]
  updated_m=(jnp.matmul(phi.T,data)/(1/sigma**2*jnp.ones(shape=(K,d))+jnp.matmul(jnp.resize(jnp.sum(phi,axis=0),(1,K)).T,jnp.ones(shape=(1,d)))))
  updated_s2=(1/(1/sigma**2*jnp.ones(shape=(K,1))+jnp.resize(jnp.sum(phi,axis=0),(1,K)).T))
  return updated_m,updated_s2

update_mean_and_variance_jit=jit(update_mean_and_variance)


def compute_ELBO(m,s2,phi,data):
  # when computing the ELBO value, we omit constants because once we compute the improvement they would have a total of 0
  # Fn stands for the nth component of the formula (21) in the review paper
  d=m.shape[1]
  M=jnp.matmul(m,m.T)

  F1=-0.5*sigma**2 *jnp.sum( d*s2+jnp.diag(M))

  # F2= -log(K) sum over k from 1 to K => constant in every iteration

  F3=-0.5*jnp.sum(jnp.matmul(phi.T,jnp.diag(jnp.matmul(data,data.T))))+jnp.sum(jnp.diag(jnp.matmul(phi.T,jnp.matmul(data,m.T))))-0.5*d*jnp.sum(jnp.matmul(phi,s2))
  F3+=-0.5*jnp.sum(jnp.matmul(phi,jnp.diag(M)))
  # -d/2*jnp.log(2*jnp.pi)*phi[i,k] summed over i and k should be constant over time, since phi[i,:] is a probability it should sum N every time

  F4=jnp.sum(jnp.log(phi)*phi)

  F5=-d/2*jnp.sum(jnp.log(s2))

  return F1+F3+F4+F5

compute_ELBO_jit=jit(compute_ELBO)

# %%
# FUNCTION FOR VARIATIONAL INFERENCE
# Notation of the paper

def single_iteration_VI(data,K,sigma,i,nMAX,tol):
    N=data.shape[0]
    d=data.shape[1]
    key = random.PRNGKey(i*seed)
    phi=random.uniform(key,minval=0,maxval=1,shape=(N,K))
    phi/=jnp.sum(phi,axis=1,keepdims=True)
    m=random.normal(key,shape=(K,d))*sigma
    s2=random.uniform(key,minval=0,maxval=10,shape=(K,1))
    improvement=1
    ELBO_old=0 # probabilmente questo andrà modificato
    ELBO_new=compute_ELBO_jit(m,s2,phi,data)
    nit=0
    while (improvement>tol and nit<nMAX) or nit<15:
      phi=update_phi_jit(data,phi,m,s2)
      m,s2=update_mean_and_variance_jit(data,phi,sigma)
      ELBO_old=ELBO_new
      ELBO_new=compute_ELBO_jit(m,s2,phi,data)
      improvement=ELBO_new-ELBO_old
      nit+=1
      #print('Iter ',nit,'\t ELBO: ',ELBO_new,'\t Improvement: ',improvement,'\n')
      #print('=================================================\n')
    return  m,s2,phi,ELBO_new,nit

single_iteration_VI_jit=jit(single_iteration_VI,static_argnames=['K','nMAX','tol'])


def VI(data,K,sigma,nMAX,n_iniz,tol):
  # creating our variables as estimation of parameters for posterior probabilities
  # jax arrays are immutable, so I don't know how to create these variables in jax and use them
  # I iniialize them randomly, since there is no a-priori starting point which is best than others
  ELBO_max=0
  for i in range(n_iniz):
    m,s2,phi,ELBO_new,nit=single_iteration_VI(data,K,sigma,i,nMAX,tol)
    if i==0:
      ELBO_max=ELBO_new
      m_max=m
      s2_max=s2
      phi_max=phi
      n_max=0
    print('Initialization number: ',i+1,'\t ELBO: ',ELBO_new,'\t N_iterations: ',nit)
    print('=================================================\n')
    if ELBO_new>ELBO_max:
      ELBO_max=ELBO_new
      m_max=m
      s2_max=s2
      phi_max=phi
      n_max=i
  print('Best initialization at ',n_max+1,' \t ELBO: ',ELBO_max,'\n\n')
  return m_max,s2_max,phi_max

VI_jit=jit(VI)

# %%
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp

def plot_clusters(data, phi, means):
    # Get the cluster assignments
    cluster_assignments = jnp.argmax(phi, axis=1)

    # Number of clusters
    num_clusters = means.shape[0]

    # Create a list of colors for plotting
    #colors = plt.colormaps()
    colors=mcp.gen_color(cmap="viridis",n=K)
    print(colors)

    # Scatter plot each data point with its assigned color
    plt.figure(figsize=(8, 6))
    for cluster in range(num_clusters):
        plt.scatter(data[cluster_assignments == cluster, 0], data[cluster_assignments == cluster, 1], c=colors[cluster], label=f'Cluster {cluster}')

    # Plot the cluster means
    for cluster in range(num_clusters):
        plt.scatter(means[cluster, 0], means[cluster, 1], marker='x', color='red', s=100, label=f'Mean Cluster {cluster}')

    plt.legend()
    plt.title('Cluster Visualization')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# %%
tol=10**-16
m,s2,phi=VI(X,K,sigma,10000,100,tol)
#print(m,'\n',mu)
#print(s2)
#print(phi,'\n',C)
# Out:
# Initialization number:  1 	 ELBO:  -2625.8208 	 N_iterations:  15
# =================================================
#
# Initialization number:  2 	 ELBO:  -2626.499 	 N_iterations:  19
# =================================================
#
# Initialization number:  3 	 ELBO:  nan 	 N_iterations:  18
# =================================================
#
# Initialization number:  4 	 ELBO:  -2626.5024 	 N_iterations:  35
# =================================================
#
# Initialization number:  5 	 ELBO:  -2861.1587 	 N_iterations:  21
# =================================================
#
# Initialization number:  6 	 ELBO:  -2626.0605 	 N_iterations:  15
# =================================================
#
# Initialization number:  7 	 ELBO:  -2626.4985 	 N_iterations:  32
# =================================================
#
# Initialization number:  8 	 ELBO:  -2626.4934 	 N_iterations:  42
# =================================================
#
# Initialization number:  9 	 ELBO:  nan 	 N_iterations:  20
# =================================================
#
# Initialization number:  10 	 ELBO:  -2626.4226 	 N_iterations:  15
# =================================================
#
# Initialization number:  11 	 ELBO:  -2626.4993 	 N_iterations:  41
# =================================================
#
# Initialization number:  12 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  13 	 ELBO:  -2626.3567 	 N_iterations:  15
# =================================================
#
# Initialization number:  14 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  15 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  16 	 ELBO:  -2626.5005 	 N_iterations:  31
# =================================================
#
# Initialization number:  17 	 ELBO:  -2626.0425 	 N_iterations:  15
# =================================================
#
# Initialization number:  18 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  19 	 ELBO:  -2626.5007 	 N_iterations:  32
# =================================================
#
# Initialization number:  20 	 ELBO:  -2969.825 	 N_iterations:  22
# =================================================
#
# Initialization number:  21 	 ELBO:  -2625.7783 	 N_iterations:  15
# =================================================
#
# Initialization number:  22 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  23 	 ELBO:  -2626.4998 	 N_iterations:  37
# =================================================
#
# Initialization number:  24 	 ELBO:  -2796.1328 	 N_iterations:  15
# =================================================
#
# Initialization number:  25 	 ELBO:  -2625.9487 	 N_iterations:  15
# =================================================
#
# Initialization number:  26 	 ELBO:  -2969.8247 	 N_iterations:  17
# =================================================
#
# Initialization number:  27 	 ELBO:  nan 	 N_iterations:  19
# =================================================
#
# Initialization number:  28 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  29 	 ELBO:  -2626.497 	 N_iterations:  32
# =================================================
#
# Initialization number:  30 	 ELBO:  -2626.5005 	 N_iterations:  36
# =================================================
#
# Initialization number:  31 	 ELBO:  -2969.7935 	 N_iterations:  15
# =================================================
#
# Initialization number:  32 	 ELBO:  -2626.5054 	 N_iterations:  29
# =================================================
#
# Initialization number:  33 	 ELBO:  -2626.074 	 N_iterations:  16
# =================================================
#
# Initialization number:  34 	 ELBO:  -2969.8208 	 N_iterations:  25
# =================================================
#
# Initialization number:  35 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  36 	 ELBO:  -2969.771 	 N_iterations:  15
# =================================================
#
# Initialization number:  37 	 ELBO:  -2626.5027 	 N_iterations:  32
# =================================================
#
# Initialization number:  38 	 ELBO:  -2969.8223 	 N_iterations:  23
# =================================================
#
# Initialization number:  39 	 ELBO:  -2625.67 	 N_iterations:  16
# =================================================
#
# Initialization number:  40 	 ELBO:  -2625.9521 	 N_iterations:  17
# =================================================
#
# Initialization number:  41 	 ELBO:  -2823.2864 	 N_iterations:  15
# =================================================
#
# Initialization number:  42 	 ELBO:  nan 	 N_iterations:  19
# =================================================
#
# Initialization number:  43 	 ELBO:  -2625.8125 	 N_iterations:  15
# =================================================
#
# Initialization number:  44 	 ELBO:  -2969.8196 	 N_iterations:  29
# =================================================
#
# Initialization number:  45 	 ELBO:  -2626.5122 	 N_iterations:  30
# =================================================
#
# Initialization number:  46 	 ELBO:  -2626.1191 	 N_iterations:  16
# =================================================
#
# Initialization number:  47 	 ELBO:  -2625.998 	 N_iterations:  18
# =================================================
#
# Initialization number:  48 	 ELBO:  -2625.9912 	 N_iterations:  25
# =================================================
#
# Initialization number:  49 	 ELBO:  -2969.822 	 N_iterations:  24
# =================================================
#
# Initialization number:  50 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  51 	 ELBO:  -2626.1606 	 N_iterations:  23
# =================================================
#
# Initialization number:  52 	 ELBO:  -2625.8875 	 N_iterations:  16
# =================================================
#
# Initialization number:  53 	 ELBO:  -2861.0095 	 N_iterations:  15
# =================================================
#
# Initialization number:  54 	 ELBO:  -2626.4917 	 N_iterations:  36
# =================================================
#
# Initialization number:  55 	 ELBO:  -2626.1294 	 N_iterations:  16
# =================================================
#
# Initialization number:  56 	 ELBO:  -2969.8235 	 N_iterations:  23
# =================================================
#
# Initialization number:  57 	 ELBO:  -2626.1423 	 N_iterations:  17
# =================================================
#
# Initialization number:  58 	 ELBO:  -2626.4968 	 N_iterations:  34
# =================================================
#
# Initialization number:  59 	 ELBO:  -2626.5054 	 N_iterations:  30
# =================================================
#
# Initialization number:  60 	 ELBO:  -2692.3657 	 N_iterations:  15
# =================================================
#
# Initialization number:  61 	 ELBO:  -2626.5044 	 N_iterations:  40
# =================================================
#
# Initialization number:  62 	 ELBO:  -2824.3945 	 N_iterations:  15
# =================================================
#
# Initialization number:  63 	 ELBO:  -2626.1343 	 N_iterations:  20
# =================================================
#
# Initialization number:  64 	 ELBO:  -2626.2349 	 N_iterations:  15
# =================================================
#
# Initialization number:  65 	 ELBO:  -2626.115 	 N_iterations:  19
# =================================================
#
# Initialization number:  66 	 ELBO:  -2969.8213 	 N_iterations:  24
# =================================================
#
# Initialization number:  67 	 ELBO:  -2626.059 	 N_iterations:  31
# =================================================
#
# Initialization number:  68 	 ELBO:  -2626.0498 	 N_iterations:  19
# =================================================
#
# Initialization number:  69 	 ELBO:  -2626.5 	 N_iterations:  40
# =================================================
#
# Initialization number:  70 	 ELBO:  -2860.9988 	 N_iterations:  15
# =================================================
#
# Initialization number:  71 	 ELBO:  -2626.5046 	 N_iterations:  41
# =================================================
#
# Initialization number:  72 	 ELBO:  -2626.4924 	 N_iterations:  48
# =================================================
#
# Initialization number:  73 	 ELBO:  -2626.8035 	 N_iterations:  15
# =================================================
#
# Initialization number:  74 	 ELBO:  -2969.8208 	 N_iterations:  25
# =================================================
#
# Initialization number:  75 	 ELBO:  -2626.4995 	 N_iterations:  36
# =================================================
#
# Initialization number:  76 	 ELBO:  -2625.9744 	 N_iterations:  15
# =================================================
#
# Initialization number:  77 	 ELBO:  nan 	 N_iterations:  23
# =================================================
#
# Initialization number:  78 	 ELBO:  -2626.7102 	 N_iterations:  15
# =================================================
#
# Initialization number:  79 	 ELBO:  -2626.034 	 N_iterations:  20
# =================================================
#
# Initialization number:  80 	 ELBO:  nan 	 N_iterations:  15
# =================================================
#
# Initialization number:  81 	 ELBO:  -2626.1846 	 N_iterations:  15
# =================================================
#
# Initialization number:  82 	 ELBO:  -2823.8977 	 N_iterations:  15
# =================================================
#
# Initialization number:  83 	 ELBO:  nan 	 N_iterations:  19
# =================================================
#
# Initialization number:  84 	 ELBO:  -2625.3784 	 N_iterations:  19
# =================================================
#
# Initialization number:  85 	 ELBO:  -2626.4258 	 N_iterations:  15
# =================================================
#
# Initialization number:  86 	 ELBO:  -2969.8198 	 N_iterations:  26
# =================================================
#
# Initialization number:  87 	 ELBO:  -2626.5056 	 N_iterations:  40
# =================================================
#
# Initialization number:  88 	 ELBO:  -2626.4985 	 N_iterations:  33
# =================================================
#
# Initialization number:  89 	 ELBO:  -2626.5012 	 N_iterations:  44
# =================================================
#
# Initialization number:  90 	 ELBO:  -2626.0408 	 N_iterations:  20
# =================================================
#
# Initialization number:  91 	 ELBO:  -2626.4995 	 N_iterations:  38
# =================================================
#
# Initialization number:  92 	 ELBO:  -2969.8218 	 N_iterations:  22
# =================================================
#
# Initialization number:  93 	 ELBO:  -2626.501 	 N_iterations:  37
# =================================================
#
# Initialization number:  94 	 ELBO:  -2626.046 	 N_iterations:  27
# =================================================
#
# Initialization number:  95 	 ELBO:  -2969.7847 	 N_iterations:  15
# =================================================
#
# Initialization number:  96 	 ELBO:  -2625.7075 	 N_iterations:  16
# =================================================
#
# Initialization number:  97 	 ELBO:  -2626.1426 	 N_iterations:  26
# =================================================
#
# Initialization number:  98 	 ELBO:  -2626.2231 	 N_iterations:  20
# =================================================
#
# Initialization number:  99 	 ELBO:  -2860.8335 	 N_iterations:  15
# =================================================
#
# Initialization number:  100 	 ELBO:  -2626.4993 	 N_iterations:  40
# =================================================
#
# Best initialization at  84  	 ELBO:  -2625.3784

# %%
# Eslicitiamo la likehood di muk rispetto ai dati
n_cluster = np.sum(C, axis = 0)
m_post=1/(1+1/sigma**2)/np.matmul(n_cluster.reshape((K,1)),np.ones(shape=(1,d)))*np.matmul(C.T,X)
s2_post=1/(1+1/sigma**2)/n_cluster

plot_clusters(X, phi, m)

for i in range(K):
  plt.scatter(X[c==i,0],X[c==i,1])
plt.show()
# Out:
# ['#440154', '#3b528b', '#21918c', '#5ec962', '#fde725']

# %% [markdown]
# TUTTO DA CONTROLLARE QUA, CLUSTER E MEDIE NON ORDINATI QUINDI STIAMO CONFRONTANDO VALORI CON ORDINE CASUALE
#
# DOBBIAMO TROVARE UN MODO DI ORDINARE MEDIE E CLUSTER PER OTTENERLI NELLO STESSO ORDINE
# SE NON CI RIUSCIAMO AMEN, NESSUNO CI HA CHIESTO DI FARE QUESTO ERRORE

# %%
def error_measure(m_real,s2_real,clus_real,m_pred,s2_pred,clus_pred):
  N=clus_real.shape[0]
  K=m_real.shape[0]
  error_m=1/K*jnp.linalg.norm(m_real-m_pred)
  error_s2=1/K*jnp.linalg.norm(s2_real-s2_pred)
  error_clust=1/N*jnp.count_nonzero(clus_real-clus_pred)
  return error_m,error_s2,error_clust

# %%
clus_pred=jnp.reshape(jnp.argmax(phi,axis=1,keepdims=True),(N,))
error_m,error_s2,error_clust=error_measure(m_post,s2_post,c,m,s2,clus_pred)
error_m,error_s2,error_clust
# Out:
# (Array(2.9955854, dtype=float32),
#  Array(0.00043461, dtype=float32),
#  Array(0.95300007, dtype=float32, weak_type=True))
